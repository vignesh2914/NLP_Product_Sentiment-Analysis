# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# df = pd.read_csv("/content/B019T0K132_combined.csv")

df = pd.read_csv("/content/amazon2.csv")

# %%
df
# Out:
#                                             review_text  \
# 0     I have received a fake product. There are worm...
# 1     Powder had white particles (God knows what wer...
# 2     Seems they have started mixing plant based pro...
# 3     Duplicate product... By consuming I got itchin...
# 4                                          Fake product
# ...                                                 ...
# 1287    Go for it. The package has a verification seal.
# 1288  Easy to handle and carry in gym bag. Also I ca...
# 1289                                   Very good flavor
# 1290  It's a bit expensive but at least there's no f...
# 1291  I am currently working out for more than a yea...
#
#                                  review_date  \
# 0          Reviewed in India on 12 July 2024
# 1     Reviewed in India on 10 September 2024
# 2      Reviewed in India on 5 September 2024
# 3      Reviewed in India on 5 September 2024
# 4     Reviewed in India on 13 September 2024
# ...                                      ...
# 1287    Reviewed in India on 21 January 2023
# 1288     Reviewed in India on 12 August 2022
# 1289        Reviewed in India on 17 May 2023
# 1290       Reviewed in India on 28 June 2022
# 1291   Reviewed in India on 19 December 2016
#
#                                            flavour_name  star_rating
# 0               Flavour Name: Alphonso MangoSize: 2 Lbs            1
# 1        Flavour Name: Double Rich ChocolateSize: 2 Lbs            1
# 2        Flavour Name: Double Rich ChocolateSize: 2 Lbs            1
# 3     Flavour Name: Double Rich ChocolateSize: 3.7 L...            1
# 4        Flavour Name: Double Rich ChocolateSize: 2 Lbs            1
# ...                                                 ...          ...
# 1287     Flavour Name: Double Rich ChocolateSize: 1 Lbs            5
# 1288  Flavour Name: Double Rich ChocolateSize: Singl...            5
# 1289                   Flavour Name: VanillaSize: 1 Lbs            5
# 1290  Flavour Name: Double Rich ChocolateSize: Singl...            5
# 1291     Flavour Name: Double Rich ChocolateSize: 1 Lbs            5
#
# [1292 rows x 4 columns]

# %%
df['star_rating'].value_counts()
# Out:
# star_rating
# 1    300
# 5    300
# 4    261
# 3    240
# 2    191
# Name: count, dtype: int64

# %%
unique_flavours = df["star_rating"].unique()
print(unique_flavours)
# Out:
# [1 2 3 4 5]

# %%
df.shape
# Out:
# (1292, 4)

# %%
df['flavour_name'].value_counts()
# Out:
# flavour_name
# Flavour Name: Double Rich ChocolateSize: 1 Lbs                             346
# Flavour Name: Double Rich ChocolateSize: 2 Lbs                             309
# Flavour Name: Double Rich ChocolateSize: 8.8 Lbs                           113
# Flavour Name: Mocha CappuchinoSize: 5 Lbs                                   85
# Flavour Name: VanillaSize: 1 Lbs                                            70
# Flavour Name: Double Rich ChocolateSize: Single Serve Sachets (5 Count)     56
# Flavour Name: Alphonso MangoSize: 2 Lbs                                     54
# Flavour Name: Cookies & CreamSize: 5 Lbs                                    49
# Flavour Name: Vanilla Ice CreamSize: 2 Lbs                                  43
# Flavour Name: Extreme Milk ChocolateSize: 5 Lbs                             42
# Flavour Name: Vanilla Ice CreamSize: 8.8 Lbs                                30
# Flavour Name: Double Rich ChocolateSize: 3.7 Lbs (1.7 Kg )                  24
# Flavour Name: Extreme Milk ChocolateSize: 2 Lbs                             16
# Flavour Name: Cookies & CreamSize: 2 Lbs                                    15
# Flavour Name: Mocha CappucinoSize: 2 Lbs                                    14
# Flavour Name: StrawberrySize: 2 Lbs                                         11
# Name: count, dtype: int64

# %%
df['review_text'] = df['review_text'].str.lower()
print(df['review_text'].iloc[0])  # Check the first row or change the index as needed

df.head()
# Out:
# i have received a fake product. there are worms in the protein powder. it looks like a lot of flour (atta) has been mixed in it. tastes awful as well. i found out that there is a cut on the packaging. someone smartly removed the whey and added flour (atta) with worms and put the label back. the cut was made deep down the jar so that the user does not notice it until he has consumed a lot of the product. very disappointed. my diabetic father consumed it and had to visit the doctor twice due to severe digestive problems after consuming this. i don't know who to turn to for help.
#                                          review_text  \
# 0  i have received a fake product. there are worm...
# 1  powder had white particles (god knows what wer...
# 2  seems they have started mixing plant based pro...
# 3  duplicate product... by consuming i got itchin...
# 4                                       fake product
#
#                               review_date  \
# 0       Reviewed in India on 12 July 2024
# 1  Reviewed in India on 10 September 2024
# 2   Reviewed in India on 5 September 2024
# 3   Reviewed in India on 5 September 2024
# 4  Reviewed in India on 13 September 2024
#
#                                         flavour_name  star_rating
# 0            Flavour Name: Alphonso MangoSize: 2 Lbs            1
# 1     Flavour Name: Double Rich ChocolateSize: 2 Lbs            1
# 2     Flavour Name: Double Rich ChocolateSize: 2 Lbs            1
# 3  Flavour Name: Double Rich ChocolateSize: 3.7 L...            1
# 4     Flavour Name: Double Rich ChocolateSize: 2 Lbs            1

# %%
import re
emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # Emoticons
                           u"\U0001F300-\U0001F5FF"  # Symbols & Pictographs
                           u"\U0001F680-\U0001F6FF"  # Transport & Map Symbols
                           u"\U0001F1E0-\U0001F1FF"  # Flags (iOS)
                           u"\U00002500-\U00002BEF"  # Chinese characters
                           u"\U00002702-\U000027B0"  # Miscellaneous symbols
                           u"\U000024C2-\U0001F251"  # Enclosed characters
                           u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                           "]+", flags=re.UNICODE)
df['review_text'] = df['review_text'].str.replace(emoji_pattern, '', regex=True)

# %%
df['review_text'] = df['review_text'].str.replace(r'[^a-zA-Z0-9\s]', ' ', regex=True)

# %%
df.head()
# Out:
#                                          review_text  \
# 0  i have received a fake product  there are worm...
# 1  powder had white particles  god knows what wer...
# 2  seems they have started mixing plant based pro...
# 3  duplicate product    by consuming i got itchin...
# 4                                       fake product
#
#                               review_date  \
# 0       Reviewed in India on 12 July 2024
# 1  Reviewed in India on 10 September 2024
# 2   Reviewed in India on 5 September 2024
# 3   Reviewed in India on 5 September 2024
# 4  Reviewed in India on 13 September 2024
#
#                                         flavour_name  star_rating
# 0            Flavour Name: Alphonso MangoSize: 2 Lbs            1
# 1     Flavour Name: Double Rich ChocolateSize: 2 Lbs            1
# 2     Flavour Name: Double Rich ChocolateSize: 2 Lbs            1
# 3  Flavour Name: Double Rich ChocolateSize: 3.7 L...            1
# 4     Flavour Name: Double Rich ChocolateSize: 2 Lbs            1

# %%
print("Original shape:", df.shape)
print("Sample data before transformations:")
print(df['review_text'].head(10))
# Out:
# Original shape: (1292, 4)
# Sample data before transformations:
# 0    i have received a fake product  there are worm...
# 1    powder had white particles  god knows what wer...
# 2    seems they have started mixing plant based pro...
# 3    duplicate product    by consuming i got itchin...
# 4                                         fake product
# 5                          throat itching and full gas
# 6    the packaging and box of item was big but the ...
# 7    as soon as you open the jar but dont find it s...
# 8    the product is duplicate   no use of the uniqu...
# 9               seal wasnt there and the lid was loose
# Name: review_text, dtype: object

# %%
import nltk
from nltk.corpus import stopwords


nltk.download('stopwords')
df['review_text'] = df['review_text'].apply(
    lambda x: " ".join([word for word in str(x).split() if word not in stopwords.words('english')]) if isinstance(x, str) else x
)

print("Shape after stopword removal:", df.shape)
print("Sample data after stopword removal:")
print(df['review_text'].head(10))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Shape after stopword removal: (1292, 4)
# Sample data after stopword removal:
# 0    received fake product worms protein powder loo...
# 1    powder white particles god knows labels added ...
# 2    seems started mixing plant based protein powde...
# 3    duplicate product consuming got itching whole ...
# 4                                         fake product
# 5                              throat itching full gas
# 6    packaging box item big amount less never shopping
# 7    soon open jar dont find sealed return unfortun...
# 8       product duplicate use unique verification code
# 9                                 seal wasnt lid loose
# Name: review_text, dtype: object

# %%
# Remove special characters
df['review_text'] = df['review_text'].apply(
    lambda x: " ".join([word for word in str(x).translate(str.maketrans('', '', '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~')).split() if word not in stopwords.words('english')]) if isinstance(x, str) else x
)

print("Shape after special character removal:", df.shape)
print("Sample data after special character removal:")
print(df['review_text'].head(10))
# Out:
# Shape after special character removal: (1292, 4)
# Sample data after special character removal:
# 0    received fake product worms protein powder loo...
# 1    powder white particles god knows labels added ...
# 2    seems started mixing plant based protein powde...
# 3    duplicate product consuming got itching whole ...
# 4                                         fake product
# 5                              throat itching full gas
# 6    packaging box item big amount less never shopping
# 7    soon open jar dont find sealed return unfortun...
# 8       product duplicate use unique verification code
# 9                                 seal wasnt lid loose
# Name: review_text, dtype: object

# %%
# Replace multiple spaces with a single space
df['review_text'] = df['review_text'].str.replace(r'\s+', ' ', regex=True)

# Final clean-up
df['review_text'] = df['review_text'].str.strip()

print("Final shape:", df.shape)
print("Final sample data:")
print(df['review_text'].head(10))
# Out:
# Final shape: (1292, 4)
# Final sample data:
# 0    received fake product worms protein powder loo...
# 1    powder white particles god knows labels added ...
# 2    seems started mixing plant based protein powde...
# 3    duplicate product consuming got itching whole ...
# 4                                         fake product
# 5                              throat itching full gas
# 6    packaging box item big amount less never shopping
# 7    soon open jar dont find sealed return unfortun...
# 8       product duplicate use unique verification code
# 9                                 seal wasnt lid loose
# Name: review_text, dtype: object

# %%
# Find the entry that became empty
empty_entry = df[df['review_text'].str.strip() == '']
print("Empty entry details:")
print(empty_entry)
# Out:
# Empty entry details:
#      review_text                            review_date  \
# 13                    Reviewed in India on 31 July 2024
# 973               Reviewed in India on 13 December 2018
# 1060              Reviewed in India on 10 November 2019
# 1078               Reviewed in India on 24 January 2019
#
#                                         flavour_name  star_rating
# 13           Flavour Name: Alphonso MangoSize: 2 Lbs            1
# 973   Flavour Name: Double Rich ChocolateSize: 1 Lbs            2
# 1060  Flavour Name: Double Rich ChocolateSize: 1 Lbs            3
# 1078  Flavour Name: Double Rich ChocolateSize: 1 Lbs            3

# %%
df.head()
# Out:
#                                          review_text  \
# 0  received fake product worms protein powder loo...
# 1  powder white particles god knows labels added ...
# 2  seems started mixing plant based protein powde...
# 3  duplicate product consuming got itching whole ...
# 4                                       fake product
#
#                               review_date  \
# 0       Reviewed in India on 12 July 2024
# 1  Reviewed in India on 10 September 2024
# 2   Reviewed in India on 5 September 2024
# 3   Reviewed in India on 5 September 2024
# 4  Reviewed in India on 13 September 2024
#
#                                         flavour_name  star_rating
# 0            Flavour Name: Alphonso MangoSize: 2 Lbs            1
# 1     Flavour Name: Double Rich ChocolateSize: 2 Lbs            1
# 2     Flavour Name: Double Rich ChocolateSize: 2 Lbs            1
# 3  Flavour Name: Double Rich ChocolateSize: 3.7 L...            1
# 4     Flavour Name: Double Rich ChocolateSize: 2 Lbs            1

# %%
import gensim
from gensim.models import Word2Vec, KeyedVectors

# %%
import re
import nltk
import re
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import re
import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')


df['review_text'].fillna('', inplace=True)

# Now you can continue with lemmatization and other preprocessing
lemmatizer = WordNetLemmatizer()
corpus = []

for i in range(len(df)):
    review = re.sub('[^a-zA-Z]', ' ', df['review_text'][i])
    review = review.lower()
    review = review.split()

    # Lemmatize each word in the review
    review = [lemmatizer.lemmatize(word) for word in review]
    review = ' '.join(review)
    corpus.append(review)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
words= []
for sent in corpus:
  sent_token = sent_tokenize(sent)
  for sent in sent_token:
    words.append(simple_preprocess(sent))

# %%
words
# Out:
# [['received',
#   'fake',
#   'product',
#   'worm',
#   'protein',
#   'powder',
#   'look',
#   'like',
#   'lot',
#   'flour',
#   'atta',
#   'mixed',
#   'taste',
#   'awful',
#   'well',
#   'found',
#   'cut',
#   'packaging',
#   'someone',
#   'smartly',
#   'removed',
#   'whey',
#   'added',
#   'flour',
#   'atta',
#   'worm',
#   'put',
#   'label',
#   'back',
#   'cut',
#   'made',
#   'deep',
#   'jar',
#   'user',
#   'notice',
#   'consumed',
#   'lot',
#   'product',
#   'disappointed',
#   'diabetic',
#   'father',
#   'consumed',
#   'visit',
#   'doctor',
#   'twice',
#   'due',
#   'severe',
#   'digestive',
#   'problem',
#   'consuming',
#   'know',
#   'turn',
#   'help'],
#  ['powder',
#   'white',
#   'particle',
#   'god',
#   'know',
#   'label',
#   'added',
#   'product',
#   'name'],
#  ['seems',
#   'started',
#   'mixing',
#   'plant',
#   'based',
#   'protein',
#   'powder',
#   'irritates',
#   'throat',
#   'taste',
#   'also',
#   'give',
#   'hint',
#   'pea',
#   'protein',
#   'powder',
#   'suspect',
#   'personal',
#   'opinion'],
#  ['duplicate',
#   'product',
#   'consuming',
#   'got',
#   'itching',
#   'whole',
#   'body',
#   'applied',
#   'return',
#   'one',
#   'came',
#   'pickup'],
#  ['fake', 'product'],
#  ['throat', 'itching', 'full', 'gas'],
#  ['packaging', 'box', 'item', 'big', 'amount', 'le', 'never', 'shopping'],
#  ['soon',
#   'open',
#   'jar',
#   'dont',
#   'find',
#   'sealed',
#   'return',
#   'unfortuntely',
#   'opened',
#   'jar',
#   'month',
#   'delivery',
#   'surprised',
#   'seal',
#   'throw',
#   'away',
#   'product',
#   'worth',
#   'cant',
#   'returned'],
#  ['product', 'duplicate', 'use', 'unique', 'verification', 'code'],
#  ['seal', 'wasnt', 'lid', 'loose'],
#  ['worse',
#   'muscleblaze',
#   'ordered',
#   'alphonso',
#   'mango',
#   'flavor',
#   'mixability',
#   'pathetic',
#   'shaking',
#   'min',
#   'mix',
#   'completely',
#   'buy'],
#  ['totally', 'fake', 'product'],
#  ['authentication', 'failed', 'please', 'check', 'carefully'],
#  ['received',
#   'fake',
#   'product',
#   'checked',
#   'code',
#   'character',
#   'instead',
#   'always',
#   'check',
#   'code',
#   'using',
#   'product',
#   'aware',
#   'fake',
#   'protein',
#   'powder'],
#  ['packaging',
#   'already',
#   'loss',
#   'protein',
#   'inner',
#   'protein',
#   'already',
#   'bad',
#   'experience',
#   'authenticity'],
#  ['dont',
#   'know',
#   'whats',
#   'wrong',
#   'package',
#   'ordered',
#   'double',
#   'chocolate',
#   'taste',
#   'bitter',
#   'dark',
#   'chocolaty',
#   'bitter',
#   'mixed',
#   'water'],
#  ['seal',
#   'powder',
#   'spilled',
#   'ooening',
#   'lid',
#   'received',
#   'already',
#   'used',
#   'product'],
#  ['regular',
#   'user',
#   'product',
#   'aware',
#   'product',
#   'time',
#   'taste',
#   'product',
#   'seems',
#   'genuine',
#   'product',
#   'stomach',
#   'upset',
#   'consuming',
#   'want',
#   'return',
#   'product',
#   'amazon',
#   'seller',
#   'allow',
#   'return'],
#  ['verified',
#   'saying',
#   'legit',
#   'product',
#   'facing',
#   'following',
#   'problem',
#   'seal',
#   'present',
#   'yes',
#   'one',
#   'top',
#   'brand',
#   'seal',
#   'give',
#   'code',
#   'box',
#   'box',
#   'lid',
#   'easily',
#   'slided',
#   'additional',
#   'thing',
#   'added',
#   'supposed',
#   'eat',
#   'box',
#   'protein',
#   'inside',
#   'even',
#   'cady',
#   'better',
#   'wraped',
#   'whey',
#   'soluble',
#   'part',
#   'stay',
#   'top',
#   'mixed',
#   'milk',
#   'cold',
#   'well',
#   'hot',
#   'milk',
#   'expect',
#   'world',
#   'renowned',
#   'brand',
#   'like',
#   'take',
#   'much',
#   'time',
#   'mix',
#   'september',
#   'got',
#   'product',
#   'mfg',
#   'date',
#   'june',
#   'although',
#   'expired',
#   'yet',
#   'getting',
#   'yr',
#   'late',
#   'product',
#   'never',
#   'buy',
#   'anything',
#   'ever'],
#  ['seems',
#   'fake',
#   'taste',
#   'bad',
#   'sm',
#   'authentication',
#   'yielded',
#   'response'],
#  ['heard',
#   'scam',
#   'buying',
#   'protein',
#   'powder',
#   'online',
#   'experienced',
#   'first',
#   'timethe',
#   'product',
#   'completely',
#   'sealed',
#   'time',
#   'delivery',
#   'opened',
#   'protein',
#   'powder',
#   'content',
#   'box',
#   'rest',
#   'box',
#   'empty'],
#  ['product',
#   'blatant',
#   'duplicate',
#   'original',
#   'otherwise',
#   'good',
#   'quality',
#   'protein',
#   'powder',
#   'never',
#   'ordering',
#   'protein',
#   'amazon'],
#  ['powder',
#   'box',
#   'adulterated',
#   'sticking',
#   'box',
#   'smell',
#   'fine',
#   'bitter',
#   'taste',
#   'product',
#   'made',
#   'india',
#   'confused',
#   'export',
#   'product',
#   'quality',
#   'mark',
#   'sadly',
#   'cannot',
#   'refunded',
#   'either',
#   'buy',
#   'pregnant',
#   'woman',
#   'safe'],
#  ['vertigo',
#   'dizziness',
#   'creates',
#   'false',
#   'sense',
#   'surroundings',
#   'spinning',
#   'moving',
#   'may',
#   'associated',
#   'nausea',
#   'vomiting',
#   'sweating',
#   'difficulty',
#   'walking',
#   'cardboard',
#   'box',
#   'product',
#   'delivered',
#   'absolutely',
#   'damaged',
#   'product',
#   'genuine',
#   'site',
#   'seems',
#   'box',
#   'cut',
#   'sealed',
#   'back',
#   'bottom',
#   'sample',
#   'enough',
#   'induce',
#   'swaying',
#   'sensation',
#   'still',
#   'powder',
#   'probably',
#   'throw',
#   'drain',
#   'toilet',
#   'loss',
#   'plus',
#   'doctor',
#   'fee',
#   'medicine',
#   'buy',
#   'brick',
#   'mortar',
#   'store'],
#  ['protein',
#   'powder',
#   'fake',
#   'waste',
#   'money',
#   'buying',
#   'think',
#   'powder',
#   'mixed',
#   'wheat',
#   'flour',
#   'actually',
#   'would',
#   'say',
#   'wheat',
#   'flour',
#   'mixed',
#   'small',
#   'quantity',
#   'chocolate',
#   'powder'],
#  ['tried',
#   'verification',
#   'using',
#   'secret',
#   'code',
#   'check',
#   'genuine',
#   'get',
#   'reply',
#   'think',
#   'duplicate',
#   'fooled'],
#  ['got',
#   'delivered',
#   'today',
#   'evening',
#   'opened',
#   'induction',
#   'seal',
#   'felt',
#   'strange',
#   'compared',
#   'pack',
#   'earlier',
#   'used',
#   'empty',
#   'box',
#   'also',
#   'ordered',
#   'amazon',
#   'see',
#   'photo',
#   'right',
#   'bottom',
#   'one',
#   'portrait',
#   'pic',
#   'one',
#   'earlier',
#   'used',
#   'box',
#   'pic',
#   'label',
#   'size',
#   'different',
#   'brand',
#   'font',
#   'size',
#   'different',
#   'look',
#   'feel',
#   'box',
#   'different',
#   'lid',
#   'bottle',
#   'different',
#   'shape',
#   'side',
#   'different',
#   'grain',
#   'top',
#   'tried',
#   'scratch',
#   'code',
#   'authentic',
#   'verification',
#   'come',
#   'completely',
#   'get',
#   'see',
#   'code',
#   'validation',
#   'please',
#   'consider',
#   'fact',
#   'money',
#   'health',
#   'stake'],
#  ['tried', 'verify', 'product', 'code', 'verify', 'worried', 'genuine'],
#  ['medium',
#   'could',
#   'loaded',
#   'package',
#   'quality',
#   'instruction',
#   'sticker',
#   'bad',
#   'india',
#   'manuf',
#   'double',
#   'chocolate',
#   'flavour',
#   'look',
#   'compromised',
#   'cost',
#   'compared',
#   'imported',
#   'hope',
#   'similarly',
#   'inner',
#   'content',
#   'protein',
#   'powder',
#   'compromised',
#   'difficult',
#   'say',
#   'compromise',
#   'evident',
#   'brand',
#   'sticker',
#   'proof',
#   'may',
#   'compromise',
#   'quality',
#   'profit',
#   'local',
#   'manuf',
#   'plus',
#   'still',
#   'price',
#   'consumer',
#   'buy',
#   'localised',
#   'product',
#   'quality',
#   'compromise',
#   'may',
#   'buy',
#   'brand',
#   'imported',
#   'india',
#   'food',
#   'quality',
#   'check',
#   'cannot',
#   'trusted',
#   'stringent',
#   'usa',
#   'quality',
#   'bad',
#   'trust',
#   'system',
#   'authentication',
#   'system',
#   'authenticated',
#   'product',
#   'look',
#   'compromised',
#   'manufactured',
#   'india',
#   'hidden',
#   'sticker',
#   'reason',
#   'know',
#   'seems',
#   'optimum',
#   'nutrition',
#   'want',
#   'profit',
#   'brand',
#   'tom',
#   'dick',
#   'harry',
#   'manuf',
#   'india'],
#  ['using',
#   'chocolate',
#   'flavour',
#   'good',
#   'ordered',
#   'mistake',
#   'frothy',
#   'sweet',
#   'doubt',
#   'original'],
#  ['swelled', 'gall', 'bladder', 'enlarged', 'spleen', 'nothing', 'poison'],
#  ['product',
#   'fake',
#   'receive',
#   'message',
#   'sent',
#   'product',
#   'official',
#   'number',
#   'verify'],
#  ['mango', 'flavour', 'mixability', 'issue'],
#  ['cheap',
#   'low',
#   'quality',
#   'product',
#   'please',
#   'buy',
#   'face',
#   'health',
#   'issue',
#   'help',
#   'received',
#   'side',
#   'place',
#   'buy'],
#  ['medium',
#   'could',
#   'loaded',
#   'like',
#   'bottom',
#   'product',
#   'seems',
#   'like',
#   'refilled',
#   'fake',
#   'powder',
#   'even',
#   'get',
#   'replacement'],
#  ['medium',
#   'could',
#   'loaded',
#   'product',
#   'authentication',
#   'able',
#   'authenticate',
#   'product',
#   'website',
#   'sticker',
#   'unique',
#   'code',
#   'come',
#   'get',
#   'unique',
#   'code',
#   'last',
#   'product',
#   'purchased',
#   'thru',
#   'local',
#   'seller',
#   'able',
#   'remove',
#   'unique',
#   'code',
#   'sticker',
#   'easily',
#   'authenticated',
#   'product',
#   'manufacturing',
#   'date',
#   'product',
#   'manufacturing',
#   'date',
#   'batch',
#   'number',
#   'detail',
#   'quality',
#   'product',
#   'power',
#   'moisture',
#   'compared',
#   'earlier',
#   'product',
#   'also',
#   'aroma',
#   'seems',
#   'like',
#   'old',
#   'stock',
#   'itemplease',
#   'buy'],
#  ['ordered',
#   'feb',
#   'received',
#   'feb',
#   'could',
#   'authenticate',
#   'product',
#   'customer',
#   'care',
#   'authentication',
#   'product',
#   'behalf',
#   'wonder',
#   'different',
#   'procedure',
#   'got',
#   'authentication',
#   'right',
#   'way',
#   'opened',
#   'jar',
#   'seal',
#   'inside',
#   'protect',
#   'moisture',
#   'able',
#   'mix',
#   'well',
#   'water',
#   'smell',
#   'something',
#   'weird',
#   'also',
#   'taste',
#   'something',
#   'like',
#   'cough',
#   'syrup',
#   'nothing',
#   'like',
#   'double',
#   'chocolate',
#   'consistency',
#   'wattery',
#   'mixing',
#   'day',
#   'return',
#   'replacement',
#   'total',
#   'scam',
#   'product',
#   'believe',
#   'tab',
#   'product',
#   'say',
#   'try',
#   'get',
#   'replaced',
#   'try',
#   'return',
#   'connect',
#   'amazon',
#   'customer',
#   'care',
#   'turn',
#   'ask',
#   'mail',
#   'connect',
#   'manufacturer',
#   'overall',
#   'worth',
#   'disappointment',
#   'buy',
#   'product',
#   'online'],
#  ['medium',
#   'could',
#   'loaded',
#   'ordered',
#   'received',
#   'product',
#   'march',
#   'consumed',
#   'protein',
#   'powder',
#   'notice',
#   'expiry',
#   'date',
#   'using',
#   'since',
#   'march',
#   'station',
#   'started',
#   'using',
#   'august',
#   'already',
#   'taste',
#   'good',
#   'found',
#   'lump',
#   'check',
#   'expiry',
#   'date',
#   'expired',
#   'july',
#   'manufactured',
#   'date',
#   'july',
#   'come',
#   'company',
#   'supply',
#   'product',
#   'short',
#   'expiry',
#   'date',
#   'expect',
#   'consumer',
#   'consume',
#   'quick',
#   'expensive',
#   'way',
#   'really',
#   'bad',
#   'experience',
#   'big',
#   'company'],
#  ['poor',
#   'taste',
#   'taste',
#   'double',
#   'rich',
#   'chocolate',
#   'flavour',
#   'generally',
#   'rarely',
#   'use',
#   'protein',
#   'shake',
#   'rd',
#   'time',
#   'purchased',
#   'whey',
#   'remember',
#   'first',
#   'time',
#   'purchased',
#   'product',
#   'year',
#   'back',
#   'great',
#   'taste',
#   'double',
#   'rich',
#   'chocolate',
#   'flavour',
#   'great',
#   'quality',
#   'think',
#   'usa',
#   'made',
#   'one',
#   'zero',
#   'taste',
#   'poor',
#   'quality',
#   'product'],
#  ['fake', 'product'],
#  ['fake',
#   'product',
#   'authentication',
#   'code',
#   'look',
#   'tampered',
#   'container',
#   'aluminium',
#   'foil',
#   'seal',
#   'unfortunately',
#   'family',
#   'member',
#   'used',
#   'hence',
#   'able',
#   'return',
#   'sure',
#   'fake'],
#  ['seal',
#   'powder',
#   'looked',
#   'finely',
#   'grinded',
#   'got',
#   'tasted',
#   'started',
#   'lot',
#   'acne',
#   'test',
#   'result',
#   'showed',
#   'adulterated',
#   'trust',
#   'seller'],
#  ['product',
#   'original',
#   'brand',
#   'plastic',
#   'box',
#   'packaging',
#   'tampered',
#   'protien',
#   'powder',
#   'inside',
#   'seemed',
#   'replaced',
#   'chocolate',
#   'flavoured',
#   'horlicks',
#   'like',
#   'powder'],
#  ['worst',
#   'decision',
#   'ever',
#   'buy',
#   'rich',
#   'double',
#   'chocolate',
#   'unable',
#   'return',
#   'disgusting',
#   'smell',
#   'taste',
#   'zero',
#   'chocolate',
#   'flavour',
#   'taste',
#   'like',
#   'bad',
#   'flavoured',
#   'water',
#   'worse',
#   'artificial',
#   'sweetener',
#   'added',
#   'make',
#   'taste',
#   'even',
#   'stranger'],
#  ['got', 'duplicate', 'product'],
#  ['ordered',
#   'product',
#   'january',
#   'sale',
#   'recieved',
#   'today',
#   'th',
#   'jan',
#   'happy',
#   'bought',
#   'low',
#   'price',
#   'market',
#   'soon',
#   'got',
#   'hand',
#   'product',
#   'opened',
#   'first',
#   'thing',
#   'shocked',
#   'interior',
#   'lid',
#   'covering',
#   'strange',
#   'unusual',
#   'product',
#   'always',
#   'come',
#   'interior',
#   'lid',
#   'although',
#   'seal',
#   'intact',
#   'thought',
#   'everything',
#   'right',
#   'soon',
#   'smelled',
#   'doubt',
#   'authenticity',
#   'product',
#   'becomes',
#   'crystal',
#   'clear',
#   'took',
#   'one',
#   'scoop',
#   'mixed',
#   'water',
#   'bingo',
#   'mixing',
#   'water',
#   'dont',
#   'know',
#   'happens',
#   'seal',
#   'intactand',
#   'also',
#   'distrubutor',
#   'seal',
#   'also',
#   'ok',
#   'could',
#   'happen',
#   'cant',
#   'understand',
#   'abd',
#   'protein',
#   'internet',
#   'tchao'],
#  ['amazon',
#   'selling',
#   'old',
#   'stock',
#   'platform',
#   'product',
#   'review',
#   'amazon',
#   'ask',
#   'supplier',
#   'follow',
#   'standard',
#   'protocol',
#   'relating',
#   'product',
#   'quality',
#   'better',
#   'customer',
#   'experience'],
#  ['waste', 'product'],
#  ['fake'],
#  ['mean',
#   'bad',
#   'flavor',
#   'felt',
#   'adulterated',
#   'felt',
#   'fake',
#   'mix',
#   'well',
#   'bad',
#   'term',
#   'flavor'],
#  ['stay',
#   'away',
#   'buying',
#   'product',
#   'bought',
#   'double',
#   'chocolate',
#   'flavour',
#   'box',
#   'said',
#   'double',
#   'chocolate',
#   'however',
#   'inside',
#   'different',
#   'flavour',
#   'sm',
#   'check',
#   'genuine',
#   'ness',
#   'product',
#   'also',
#   'work'],
#  ['poor', 'taste'],
#  ['careful',
#   'unboxing',
#   'product',
#   'received',
#   'jar',
#   'authenticity',
#   'seal',
#   'placed',
#   'top',
#   'another',
#   'existing',
#   'one',
#   'scratched',
#   'already',
#   'even',
#   'paper',
#   'seal',
#   'lid',
#   'missing'],
#  ['received',
#   'product',
#   'found',
#   'duplicate',
#   'one',
#   'six',
#   'digit',
#   'code',
#   'found',
#   'website',
#   'useless'],
#  ['bad',
#   'packing',
#   'box',
#   'damaged',
#   'received',
#   'bar',
#   'code',
#   'sticker',
#   'top',
#   'effectively',
#   'bar',
#   'code',
#   'one',
#   'printed',
#   'box',
#   'stuck',
#   'original',
#   'one',
#   'tried',
#   'reading',
#   'top',
#   'bar',
#   'code',
#   'found',
#   'peeled',
#   'top',
#   'bar',
#   'code',
#   'tested',
#   'one',
#   'printed',
#   'bottle',
#   'took',
#   'website',
#   'understand',
#   'bar',
#   'code',
#   'one',
#   'read',
#   'machine',
#   'whey',
#   'pounder',
#   'white',
#   'color',
#   'material',
#   'packing',
#   'seal',
#   'proper',
#   'safe',
#   'say',
#   'damaged',
#   'sure',
#   'amazon',
#   'selling',
#   'original',
#   'product',
#   'lid',
#   'bottle',
#   'opened',
#   'without',
#   'removing',
#   'seal',
#   'funny',
#   'even',
#   'whey',
#   'pounder',
#   'came',
#   'though',
#   'little',
#   'mean',
#   'may',
#   'vacuum',
#   'packed',
#   'suggests',
#   'tampering',
#   'happy'],
#  ['guess',
#   'got',
#   'fake',
#   'product',
#   'started',
#   'using',
#   'used',
#   'sweat',
#   'lot',
#   'ldl',
#   'level',
#   'increased',
#   'stopped',
#   'immediately',
#   'two',
#   'month',
#   'usuage',
#   'little',
#   'thru',
#   'youtube',
#   'genuine',
#   'product',
#   'took',
#   'box',
#   'year',
#   'notice',
#   'white',
#   'mrp',
#   'discount',
#   'sticker',
#   'put',
#   'place',
#   'bright',
#   'commodity',
#   'scratch',
#   'code',
#   'peeled',
#   'sticker',
#   'notice',
#   'scratch',
#   'card',
#   'tried',
#   'scratch',
#   'scratch',
#   'hologram',
#   'sticker',
#   'despite',
#   'scratching',
#   'show',
#   'code',
#   'please',
#   'see',
#   'pic',
#   'attached',
#   'product',
#   'expiry',
#   'box',
#   'still',
#   'half',
#   'powder',
#   'left',
#   'amazon',
#   'really',
#   'consider',
#   'monitoring',
#   'fake',
#   'product',
#   'consider',
#   'issue',
#   'seriously',
#   'take',
#   'action',
#   'seller',
#   'playing',
#   'health'],
#  ['received',
#   'fake',
#   'product',
#   'protein',
#   'dissolving',
#   'authentication',
#   'process',
#   'already',
#   'showing',
#   'authenticated',
#   'additionally',
#   'box',
#   'half',
#   'filled'],
#  ['visit',
#   'optimum',
#   'nutrition',
#   'official',
#   'website',
#   'check',
#   'genuineness',
#   'product',
#   'several',
#   'test',
#   'recommend',
#   'product',
#   'received',
#   'passed',
#   'test',
#   'absolutely',
#   'seal',
#   'completely',
#   'contrast',
#   'website',
#   'said',
#   'product',
#   'readily',
#   'available',
#   'rotate',
#   'cap',
#   'anticlockwise',
#   'use',
#   'like',
#   'every',
#   'home',
#   'container',
#   'hologram',
#   'sticker',
#   'cap',
#   'proper',
#   'place',
#   'container',
#   'bottom',
#   'matching',
#   'description',
#   'stated',
#   'official',
#   'website',
#   'performed',
#   'test',
#   'packaging',
#   'container',
#   'look',
#   'fake',
#   'way',
#   'however',
#   'used',
#   'sort',
#   'protein',
#   'clueless',
#   'test',
#   'actual',
#   'product',
#   'doubting',
#   'genuineness',
#   'product',
#   'looking',
#   'packaging',
#   'match',
#   'one',
#   'described',
#   'official',
#   'website',
#   'however',
#   'supposed',
#   'also',
#   'possible',
#   'may',
#   'genuine',
#   'product'],
#  ['even',
#   'though',
#   'could',
#   'authenticate',
#   'official',
#   'website',
#   'solubility',
#   'bad',
#   'regular',
#   'user',
#   'buying',
#   'mostly',
#   'offline',
#   'see',
#   'image',
#   'disolving',
#   'water',
#   'taste',
#   'also',
#   'good',
#   'buy',
#   'ever',
#   'offline',
#   'online'],
#  ['received',
#   'expired',
#   'product',
#   'keep',
#   'eye',
#   'mfg',
#   'date',
#   'expiry',
#   'date',
#   'packaging'],
#  ['first',
#   'whey',
#   'protein',
#   'powder',
#   'give',
#   'expected',
#   'muscle',
#   'growth',
#   'hoping',
#   'compare',
#   'protein',
#   'powder',
#   'tried',
#   'till',
#   'also',
#   'taste',
#   'maybe',
#   'absolute',
#   'beginner',
#   'period',
#   'purchased',
#   'also',
#   'came',
#   'seal',
#   'beneath',
#   'cap'],
#  ['medium', 'could', 'loaded', 'good', 'bad', 'product'],
#  ['stop',
#   'selling',
#   'old',
#   'product',
#   'customer',
#   'product',
#   'use',
#   'buy',
#   'regular',
#   'basis',
#   'product',
#   'shelf',
#   'life',
#   'year',
#   'selling',
#   'right',
#   'end',
#   'shelf',
#   'life',
#   'couple',
#   'month',
#   'left',
#   'affect',
#   'efficacy',
#   'product',
#   'stop',
#   'robbing',
#   'customer',
#   'please',
#   'dont',
#   'buy',
#   'unless',
#   'fresh',
#   'stock',
#   'highly',
#   'disappointing',
#   'attitude',
#   'coming',
#   'trusted',
#   'seller',
#   'like',
#   'cloudtail',
#   'buy',
#   'local',
#   'shop',
#   'even',
#   'cost',
#   'extra',
#   'buck',
#   'worth',
#   'using',
#   'old',
#   'product'],
#  ['allergic',
#   'gluten',
#   'purchased',
#   'advertised',
#   'gluten',
#   'free',
#   'received',
#   'product',
#   'written',
#   'bold',
#   'gluten',
#   'free',
#   'fine',
#   'print',
#   'write',
#   'processed',
#   'plant',
#   'gluten',
#   'containing',
#   'product',
#   'manufactured'],
#  ['product',
#   'recieved',
#   'going',
#   'expire',
#   'coming',
#   'month',
#   'according',
#   'amazon',
#   'okie',
#   'product',
#   'expiration',
#   'date',
#   'one',
#   'month',
#   'dear',
#   'jeff',
#   'bezoz',
#   'someone',
#   'consume',
#   'hole',
#   'protien',
#   'within',
#   'specific',
#   'period',
#   'time',
#   'going',
#   'expire',
#   'middle',
#   'stage',
#   'trainning',
#   'coordinator',
#   'sent',
#   'product',
#   'atleast',
#   'one',
#   'year',
#   'expiration',
#   'date',
#   'customer',
#   'consume',
#   'otherwise',
#   'totally',
#   'wastage',
#   'money',
#   'product',
#   'get',
#   'expire',
#   'consuming'],
#  ['fake',
#   'product',
#   'never',
#   'ever',
#   'ordered',
#   'false',
#   'seller',
#   'like',
#   'rk',
#   'world'],
#  ['use',
#   'usual',
#   'whey',
#   'protein',
#   'myselfusually',
#   'buy',
#   'shop',
#   'instructor',
#   'straight',
#   'gym',
#   'first',
#   'time',
#   'bought',
#   'online',
#   'like',
#   'taste',
#   'inside',
#   'lid',
#   'missing',
#   'sealed',
#   'transparent',
#   'plastic',
#   'outside',
#   'quite',
#   'strange',
#   'isnt',
#   'effective',
#   'experienced',
#   'usually',
#   'cant',
#   'really',
#   'comment',
#   'sancity',
#   'product',
#   'sure',
#   'something',
#   'wrong',
#   'box',
#   'received',
#   'doesnt',
#   'worth',
#   'even',
#   'buck',
#   'whereas',
#   'paid',
#   'morethan',
#   'itfor',
#   'wasted',
#   'money',
#   'lesson',
#   'learnt',
#   'go',
#   'online',
#   'come',
#   'shop',
#   'whey',
#   'protein',
#   'supplement'],
#  ['couple',
#   'day',
#   'use',
#   'weird',
#   'flavour',
#   'profile',
#   'realized',
#   'option',
#   'check',
#   'authenticity',
#   'checked',
#   'website',
#   'sm',
#   'service',
#   'verify',
#   'authenticity',
#   'either',
#   'unsure',
#   'protein',
#   'something',
#   'might',
#   'make',
#   'sick',
#   'consumption'],
#  ['expiry',
#   'date',
#   'product',
#   'genuine',
#   'product',
#   'started',
#   'behave',
#   'differently',
#   'got',
#   'body',
#   'ache',
#   'eye',
#   'started',
#   'paining',
#   'stopped',
#   'intake',
#   'whey',
#   'everything',
#   'fine',
#   'product',
#   'one',
#   'year',
#   'expiry',
#   'using',
#   'first',
#   'month',
#   'nothing',
#   'troubled',
#   'later',
#   'reacted',
#   'different',
#   'behaviour'],
#  ['think', 'originalit', 'fake', 'weird', 'taste'],
#  ['follow',
#   'ig',
#   'bodybuilding',
#   'supplement',
#   'stacki',
#   'told',
#   'customer',
#   'care',
#   'amazon',
#   'fully',
#   'imported',
#   'either',
#   'uk',
#   'place',
#   'manufacturing',
#   'plant',
#   'simple',
#   'google',
#   'search',
#   'show',
#   'tirupati',
#   'sport',
#   'nutrition',
#   'company',
#   'manufacture',
#   'brand',
#   'right',
#   'india',
#   'bottle',
#   'look',
#   'authentic',
#   'powder',
#   'inside',
#   'little',
#   'maybe',
#   'got',
#   'damaged',
#   'indian',
#   'weather',
#   'condition',
#   'maybe',
#   'indian',
#   'know',
#   'definitely',
#   'tasted',
#   'different',
#   'eating',
#   'year',
#   'got',
#   'refund',
#   'guess',
#   'complain',
#   'got',
#   'thinking',
#   'pay',
#   'premium',
#   'price',
#   'product'],
#  ['bottom',
#   'container',
#   'tampered',
#   'clearly',
#   'seen',
#   'bottom',
#   'container',
#   'cut',
#   'something',
#   'original',
#   'product',
#   'replaced',
#   'warning',
#   'health',
#   'selling',
#   'faulty',
#   'product',
#   'seriously',
#   'impact',
#   'health',
#   'double',
#   'check',
#   'every',
#   'sign',
#   'anomaly',
#   'product',
#   'even',
#   'see',
#   'slight',
#   'sign',
#   'fake',
#   'tampering',
#   'simply',
#   'return',
#   'chance',
#   'health'],
#  ['medium',
#   'could',
#   'loaded',
#   'request',
#   'amazon',
#   'take',
#   'return',
#   'give',
#   'original',
#   'protein',
#   'taking',
#   'body',
#   'losing',
#   'energy'],
#  ['product',
#   'upto',
#   'mark',
#   'serve',
#   'purpose',
#   'consuming',
#   'day',
#   'digestive',
#   'issue',
#   'bloating',
#   'issue',
#   'recommended'],
#  ['fake',
#   'product',
#   'without',
#   'seal',
#   'also',
#   'packaging',
#   'mold',
#   'open',
#   'bottom',
#   'stopped',
#   'taking',
#   'health',
#   'deteriorated',
#   'consuming',
#   'beware',
#   'buying'],
#  ['recieved',
#   'scoop',
#   'plasticscoop',
#   'net',
#   'written',
#   'bought',
#   'whey',
#   'protein',
#   'vanilla',
#   'ice',
#   'cream',
#   'flavour',
#   'bottom',
#   'print',
#   'manufacturing',
#   'batch',
#   'number',
#   'bottom',
#   'rough',
#   'compared',
#   'original',
#   'one',
#   'smooth',
#   'never',
#   'seal',
#   'inside',
#   'lid',
#   'plastic',
#   'seal',
#   'seal',
#   'always',
#   'come',
#   'top',
#   'cap',
#   'comparison',
#   'cooky',
#   'cream',
#   'flavour',
#   'bought',
#   'offline',
#   'store'],
#  ['authentication', 'working', 'could', 'fake', 'product'],
#  ['found', 'sweater', 'brand', 'purchased', 'amazon', 'costly'],
#  ['total',
#   'waste',
#   'money',
#   'per',
#   'price',
#   'total',
#   'waste',
#   'money',
#   'plls',
#   'buy',
#   'resultsplls',
#   'go'],
#  ['bye',
#   'bye',
#   'amazon',
#   'bad',
#   'experience',
#   'box',
#   'open',
#   'without',
#   'seal',
#   'seems',
#   'used',
#   'product',
#   'foul',
#   'smell',
#   'coming',
#   'taste',
#   'bad'],
#  ['medium',
#   'could',
#   'loaded',
#   'open',
#   'box',
#   'protein',
#   'whole',
#   'protein',
#   'powder',
#   'leaked',
#   'spoiled',
#   'shipping',
#   'box',
#   'want',
#   'quick',
#   'solution',
#   'plz',
#   'help'],
#  ['received', 'fake', 'product'],
#  ['smell',
#   'bad',
#   'taste',
#   'stale',
#   'bad',
#   'ordered',
#   'product',
#   'second',
#   'time',
#   'nowhere',
#   'close',
#   'earlier',
#   'one'],
#  ['buy',
#   'product',
#   'showing',
#   'day',
#   'return',
#   'policy',
#   'want',
#   'return',
#   'product',
#   'amazon',
#   'response',
#   'properly',
#   'customer',
#   'service',
#   'also',
#   'tell',
#   'contact',
#   'optimum',
#   'costumer',
#   'service',
#   'contact',
#   'also',
#   'response',
#   'worst',
#   'return',
#   'option',
#   'ever',
#   'seen',
#   'mention',
#   'amazon',
#   'costumer',
#   'service',
#   'tell',
#   'return',
#   'policy'],
#  ['since',
#   'buying',
#   'product',
#   'believed',
#   'would',
#   'provide',
#   'scoop',
#   'measure',
#   'intake',
#   'protein',
#   'believe',
#   'go',
#   'another',
#   'shop',
#   'buy',
#   'scoop'],
#  ['something', 'wrong', 'one', 'got', 'taste', 'weird'],
#  ['truly',
#   'disappointed',
#   'product',
#   'received',
#   'protien',
#   'manufactured',
#   'year',
#   'ago',
#   'expire',
#   'next',
#   'month',
#   'beware',
#   'exception',
#   'deliver',
#   'old',
#   'stock',
#   'discussed',
#   'amazon',
#   'representative',
#   'requested',
#   'replacement',
#   'said',
#   'site',
#   'mentioned',
#   'protien',
#   'expire',
#   'may',
#   'written',
#   'would',
#   'year',
#   'older',
#   'replacement',
#   'guy',
#   'please',
#   'careful',
#   'order'],
#  ['feel',
#   'baby',
#   'drink',
#   'drinking',
#   'chocolate',
#   'like',
#   'taste',
#   'useless',
#   'worthless',
#   'good',
#   'body',
#   'drink',
#   'whey',
#   'protein',
#   'since',
#   'last',
#   'year',
#   'first',
#   'time',
#   'got',
#   'baby',
#   'powder',
#   'whey',
#   'protein',
#   'clear',
#   'looting',
#   'public',
#   'dirt',
#   'cheap',
#   'price',
#   'coz',
#   'drinking',
#   'chocolate',
#   'milk',
#   'powder',
#   'rest',
#   'seems',
#   'sand',
#   'protein',
#   'paid',
#   'give',
#   'wake',
#   'call',
#   'buyer',
#   'ecommerce',
#   'bubble',
#   'bursting',
#   'fake',
#   'product',
#   'guy',
#   'started',
#   'running',
#   'money',
#   'provide',
#   'fake',
#   'product',
#   'wake',
#   'amazon',
#   'cannot',
#   'indian',
#   'buyer',
#   'really',
#   'injurious',
#   'brand',
#   'stop',
#   'giving',
#   'fake',
#   'product',
#   'useless',
#   'product',
#   'injurious',
#   'health'],
#  ['found', 'small', 'paper', 'inside', 'box', 'star'],
#  ['medium',
#   'could',
#   'loaded',
#   'fake',
#   'product',
#   'seal',
#   'authentic',
#   'bar',
#   'code',
#   'kind',
#   'malpractice',
#   'cost',
#   'money',
#   'dangerous',
#   'affect',
#   'health',
#   'please',
#   'careful',
#   'purchase'],
#  ['ordering',
#   'product',
#   'three',
#   'timesthis',
#   'time',
#   'quality',
#   'powder',
#   'patheticdont',
#   'know',
#   'time',
#   'pathetic',
#   'quality'],
#  ['please',
#   'read',
#   'purchasing',
#   'scratch',
#   'code',
#   'written',
#   'box',
#   'already',
#   'tampered',
#   'even',
#   'authenticate',
#   'genuineness',
#   'product',
#   'return',
#   'product',
#   'well',
#   'mean',
#   'option',
#   'regret',
#   'scoop',
#   'inside',
#   'also',
#   'golden',
#   'coloured',
#   'transparent',
#   'cheap',
#   'one'],
#  ['fake', 'product', 'delivered', 'please', 'buy'],
#  ['medium',
#   'could',
#   'loaded',
#   'without',
#   'tearing',
#   'neck',
#   'band',
#   'open',
#   'inside',
#   'seal',
#   'already',
#   'broken',
#   'protein',
#   'seal',
#   'please',
#   'refund',
#   'asap'],
#  ['doubt',
#   'got',
#   'original',
#   'product',
#   'filled',
#   'sugar',
#   'almost',
#   'counter',
#   'productive',
#   'weight',
#   'loss',
#   'muscle',
#   'gain'],
#  ['fake', 'item', 'original'],
#  ['common',
#   'amazon',
#   'better',
#   'regulation',
#   'fake',
#   'product',
#   'letting',
#   'thing',
#   'slip',
#   'away',
#   'fake',
#   'product',
#   'right',
#   'packaging',
#   'look',
#   'feel',
#   'taste',
#   'buy',
#   'try',
#   'source',
#   'get',
#   'genuine',
#   'one'],
#  ['absolutely',
#   'taste',
#   'flavor',
#   'taste',
#   'like',
#   'eating',
#   'raw',
#   'flour',
#   'contacted',
#   'amazon',
#   'refund',
#   'able',
#   'anything'],
#  ['able',
#   'validate',
#   'authenticity',
#   'protein',
#   'box',
#   'scoop',
#   'found',
#   'inside',
#   'leaf',
#   'questioning',
#   'authenticity',
#   'verification'],
#  ['taste', 'good', 'product', 'mentioned', 'double', 'rich', 'chocolate'],
#  ['ordered',
#   'amazon',
#   'india',
#   'consumed',
#   'son',
#   'send',
#   'product',
#   'usa',
#   'consumed',
#   'also',
#   'realised',
#   'quality',
#   'taste',
#   'difference',
#   'usa',
#   'one',
#   'far',
#   'better',
#   'amazon',
#   'india',
#   'wonder',
#   'product',
#   'brand',
#   'flavour',
#   'different'],
#  ['taste',
#   'bad',
#   'soap',
#   'like',
#   'taste',
#   'also',
#   'dissolve',
#   'well',
#   'bad',
#   'choice'],
#  ['mixing',
#   'well',
#   'water',
#   'proper',
#   'storage',
#   'problem',
#   'bad',
#   'quality',
#   'bit',
#   'confused',
#   'kindly',
#   'help'],
#  ['first',
#   'big',
#   'fan',
#   'optimum',
#   'nutrition',
#   'using',
#   'product',
#   'since',
#   'attached',
#   'screenshots',
#   'comparison',
#   'old',
#   'formula',
#   'new',
#   'formula',
#   'guy',
#   'see',
#   'difference',
#   'weight',
#   'lifting',
#   'gap',
#   'year',
#   'due',
#   'career',
#   'recently',
#   'started',
#   'lifting',
#   'bought',
#   'product',
#   'gave',
#   'digestive',
#   'issue',
#   'next',
#   'day',
#   'checked',
#   'formula',
#   'compared',
#   'old',
#   'box',
#   'find',
#   'completely',
#   'removed',
#   'digestive',
#   'enzyme',
#   'difficult',
#   'lactose',
#   'intolerant',
#   'people',
#   'removed',
#   'aminogen',
#   'patened',
#   'enzyme',
#   'lactase',
#   'formula',
#   'due',
#   'many',
#   'people',
#   'could',
#   'digestive',
#   'issue',
#   'gas',
#   'bloating',
#   'gut',
#   'irritability',
#   'etc',
#   'especially',
#   'ibs',
#   'people',
#   'tip',
#   'take',
#   'banana',
#   'fiber',
#   'feel',
#   'better'],
#  ['quality',
#   'indian',
#   'product',
#   'really',
#   'match',
#   'quality',
#   'imported',
#   'unit',
#   'imported',
#   'one',
#   'taste',
#   'time',
#   'better',
#   'mix',
#   'really',
#   'well',
#   'keep',
#   'mentioning',
#   'maintain',
#   'high',
#   'quality',
#   'standard',
#   'manufacturing',
#   'true',
#   'case',
#   'uk',
#   'manufacture',
#   'case',
#   'product',
#   'manufactured',
#   'india',
#   'yes',
#   'unit',
#   'receive',
#   'manufactured',
#   'india',
#   'tirupati',
#   'lifesciences',
#   'quality',
#   'seem',
#   'great',
#   'pay',
#   'price',
#   'imported',
#   'unit',
#   'look',
#   'quality',
#   'issue',
#   'international',
#   'manufacturing',
#   'pay',
#   'good',
#   'amount',
#   'deserve',
#   'best',
#   'quality'],
#  ['regular',
#   'user',
#   'whey',
#   'protein',
#   'first',
#   'time',
#   'getting',
#   'without',
#   'measuring',
#   'spoon',
#   'bit',
#   'confused',
#   'regarding',
#   'authenticity'],
#  ['spoon', 'purchase', 'decide', 'quantity'],
#  ['still',
#   'see',
#   'growth',
#   'whatsoever',
#   'also',
#   'feel',
#   'like',
#   'consuming',
#   'make',
#   'lazy',
#   'lethargic',
#   'never',
#   'sluggish',
#   'unproductive',
#   'also',
#   'taste',
#   'disgusting',
#   'bad',
#   'flavor',
#   'available',
#   'first',
#   'experience',
#   'product',
#   'make',
#   'puke',
#   'sometimes',
#   'also',
#   'need',
#   'either',
#   'use',
#   'blender',
#   'shake',
#   'pretty',
#   'hard',
#   'spoon',
#   'mix'],
#  ['medium',
#   'could',
#   'loaded',
#   'half',
#   'available',
#   'inside',
#   'top',
#   'cover',
#   'inside',
#   'pe',
#   'pe',
#   'written',
#   'expected',
#   'branding',
#   'sure',
#   'kg',
#   'packed',
#   'look',
#   'good',
#   'package',
#   'top',
#   'like',
#   'tight',
#   'ordered',
#   'orginal',
#   'store'],
#  ['going',
#   'rich',
#   'chocolate',
#   'taste',
#   'good',
#   'price',
#   'range',
#   'fuel',
#   'one',
#   'muscle',
#   'blaze',
#   'offer',
#   'much',
#   'better',
#   'taste',
#   'price',
#   'le'],
#  ['product',
#   'seems',
#   'genuine',
#   'worry',
#   'scoop',
#   'transparent',
#   'scoop',
#   'logo',
#   'people',
#   'use',
#   'opitimum',
#   'aware',
#   'golden',
#   'scoop',
#   'logo',
#   'authenticated',
#   'product',
#   'optimum',
#   'website',
#   'well',
#   'call',
#   'customer',
#   'care',
#   'told',
#   'due',
#   'environmental',
#   'concern',
#   'plastic',
#   'scoop',
#   'transparent',
#   'make',
#   'sense',
#   'taste',
#   'wise',
#   'ok',
#   'flavour',
#   'actual',
#   'rocky',
#   'road',
#   'flavour',
#   'except',
#   'generic',
#   'onces',
#   'vanilla',
#   'chocolate',
#   'etc',
#   'giving',
#   'star',
#   'scoop',
#   'explanation',
#   'given'],
#  ['taking',
#   'gold',
#   'standard',
#   'since',
#   'year',
#   'say',
#   'grey',
#   'market',
#   'product',
#   'definately',
#   'something',
#   'wrong',
#   'time',
#   'bright',
#   'commodity',
#   'said',
#   'genuine',
#   'product',
#   'sent',
#   'scratch',
#   'code',
#   'mixability',
#   'really',
#   'bad',
#   'even',
#   'mixing',
#   'shaker',
#   'taste',
#   'le',
#   'chocolaty',
#   'dnt',
#   'feel',
#   'heavyness',
#   'stomach',
#   'noticed',
#   'change',
#   'packaging',
#   'clearly',
#   'say',
#   'export',
#   'printing',
#   'india',
#   'fssai',
#   'green',
#   'mark',
#   'label',
#   'usa',
#   'feel',
#   'like',
#   'substandard',
#   'product',
#   'manufacturing',
#   'exclusively',
#   'people',
#   'india',
#   'dnt',
#   'know',
#   'whats',
#   'wrong',
#   'definitely',
#   'gold',
#   'standard',
#   'whey',
#   'earlier',
#   'discarding',
#   'switching',
#   'rule',
#   'wild',
#   'whey'],
#  ['recived',
#   'gold',
#   'standard',
#   'lb',
#   'double',
#   'rich',
#   'chocolate',
#   'th',
#   'november',
#   'cloudtail',
#   'seller',
#   'near',
#   'expiry',
#   'product',
#   'call',
#   'customer',
#   'care',
#   'return',
#   'pickup',
#   'recived',
#   'request',
#   'nobody',
#   'came',
#   'pickup',
#   'procedure',
#   'continuesly',
#   'day',
#   'day',
#   'receive',
#   'sm',
#   'ur',
#   'pickup',
#   'canceled',
#   'customer',
#   'care',
#   'control',
#   'amazon',
#   'logistic',
#   'team',
#   'seller',
#   'customer',
#   'care',
#   'logistic',
#   'clubbed',
#   'harassing',
#   'customer',
#   'request',
#   'customer',
#   'amazon',
#   'please',
#   'buy',
#   'nutrition',
#   'product',
#   'amazon',
#   'bcz',
#   'receive',
#   'damage',
#   'near',
#   'expiry',
#   'product',
#   'ur',
#   'product',
#   'never',
#   'pick',
#   'return',
#   'beaware',
#   'buying',
#   'nutrition',
#   'product',
#   'amazon'],
#  ['guy',
#   'wasting',
#   'plastic',
#   'much',
#   'keep',
#   'box',
#   'small',
#   'per',
#   'quantity',
#   'almost',
#   'half',
#   'empty'],
#  ['medium', 'could', 'loaded'],
#  ['dhakan',
#   'kholne',
#   'ke',
#   'baad',
#   'andar',
#   'ka',
#   'seal',
#   'ni',
#   'tha',
#   'matlab',
#   'product',
#   'hume',
#   'acha',
#   'ni',
#   'mila',
#   'ise',
#   'return',
#   'bhi',
#   'ni',
#   'kr',
#   'skte',
#   'bed'],
#  ['using',
#   'product',
#   'past',
#   'year',
#   'time',
#   'delivered',
#   'bit',
#   'unusual',
#   'packaging',
#   'proper',
#   'opened',
#   'seal',
#   'powder',
#   'spilling',
#   'also',
#   'packaging',
#   'colour',
#   'little',
#   'different',
#   'backside',
#   'sure',
#   'changed',
#   'packaging',
#   'also',
#   'always',
#   'use',
#   'double',
#   'chocolate',
#   'time',
#   'taste',
#   'also',
#   'different',
#   'texted',
#   'code',
#   'given',
#   'number',
#   'authenticated',
#   'got',
#   'verified',
#   'original',
#   'product',
#   'though'],
#  ['flavour',
#   'goodthe',
#   'quality',
#   'like',
#   'americaoptimum',
#   'nutrition',
#   'made',
#   'wrong',
#   'decisionto',
#   'manufactured',
#   'india',
#   'rd',
#   'partyplease',
#   'maintain',
#   'company',
#   'repotation'],
#  ['gold',
#   'standard',
#   'whey',
#   'longer',
#   'imported',
#   'made',
#   'india',
#   'instead',
#   'passing',
#   'benefit',
#   'international',
#   'shipping',
#   'cost',
#   'import',
#   'custom',
#   'duty',
#   'customer',
#   'increased',
#   'price',
#   'taste',
#   'also',
#   'nothing',
#   'great',
#   'would',
#   'personally',
#   'go',
#   'protein',
#   'whey',
#   'isolate',
#   'instead'],
#  ['like',
#   'product',
#   'maine',
#   'mere',
#   'husband',
#   'ke',
#   'liye',
#   'mangaya',
#   'tha',
#   'koi',
#   'result',
#   'nhi',
#   'aaya'],
#  ['taste', 'like', 'crap'],
#  ['like', 'flavour', 'mentioned'],
#  ['plastic',
#   'box',
#   'quality',
#   'average',
#   'even',
#   'spoon',
#   'hide',
#   'inside',
#   'power',
#   'insert',
#   'hand',
#   'way',
#   'inside',
#   'get',
#   'tiny',
#   'orange',
#   'spoon',
#   'flavour',
#   'awful',
#   'mix',
#   'properly',
#   'feel',
#   'like',
#   'drinking',
#   'every',
#   'day',
#   'simply',
#   'best',
#   'product',
#   'would',
#   'recommend',
#   'anyone'],
#  ['liked',
#   'flavor',
#   'well',
#   'mix',
#   'well',
#   'wateri',
#   'suspect',
#   'orginal',
#   'whey',
#   'protein',
#   'used',
#   'whye',
#   'protien',
#   'previously',
#   'mix',
#   'well',
#   'water',
#   'taste',
#   'better',
#   'taking',
#   'orginal',
#   'whey',
#   'protein',
#   'feel',
#   'energy',
#   'effect',
#   'unfortunately',
#   'felt',
#   'anything',
#   'productas',
#   'bought',
#   'need',
#   'try',
#   'day',
#   'see',
#   'total',
#   'worth'],
#  ['used',
#   'first',
#   'time',
#   'smelled',
#   'awesome',
#   'mean',
#   'like',
#   'pure',
#   'chocolate',
#   'made',
#   'shake',
#   'water',
#   'tasted',
#   'like',
#   'water',
#   'mixibility',
#   'bad',
#   'form',
#   'lump',
#   'know',
#   'contains',
#   'sugar',
#   'taste',
#   'plane',
#   'mixed',
#   'water',
#   'smell',
#   'bad',
#   'checked',
#   'product',
#   'bright',
#   'commodity',
#   'showed',
#   'product',
#   'authentic',
#   'know',
#   'still',
#   'issue',
#   'may',
#   'india',
#   'product',
#   'actually',
#   'authentic',
#   'sure'],
#  ['trusted',
#   'clouldtail',
#   'buy',
#   'supplement',
#   'believing',
#   'would',
#   'get',
#   'original',
#   'product',
#   'bright',
#   'commodity',
#   'hologram',
#   'found',
#   'persuasive',
#   'enough',
#   'try',
#   'real',
#   'thing',
#   'come',
#   'result',
#   'see',
#   'visible',
#   'result',
#   'month',
#   'time',
#   'pack',
#   'bought',
#   'abroad',
#   'gave',
#   'good',
#   'visible',
#   'result',
#   'within',
#   'month',
#   'hereafter',
#   'would',
#   'prefer',
#   'buying',
#   'bodybuilding',
#   'com',
#   'directly'],
#  ['product',
#   'delivered',
#   'nov',
#   'date',
#   'import',
#   'may',
#   'expiry',
#   'may',
#   'mention',
#   'nearing',
#   'expiry',
#   'product',
#   'description',
#   'please',
#   'refrain',
#   'concealing',
#   'information'],
#  ['frankly',
#   'satisfied',
#   'product',
#   'quantity',
#   'seemed',
#   'le',
#   'usual',
#   'protein',
#   'powder',
#   'packaging',
#   'kind',
#   'seemed',
#   'pre',
#   'used'],
#  ['tasted', 'bad', 'realized', 'bought', 'product', 'close', 'expiry', 'date'],
#  ['se', 'kuch', 'nhi', 'hota', 'useless', 'product'],
#  ['coffee', 'drinker', 'low', 'tolerance', 'caffeine', 'keep', 'night'],
#  ['better'],
#  ['product', 'almost', 'yr', 'old', 'happy'],
#  ['bought',
#   'chocolate',
#   'flavour',
#   'taste',
#   'really',
#   'bad',
#   'taste',
#   'wise',
#   'ultimate',
#   'nutration',
#   'better',
#   'value',
#   'money',
#   'well'],
#  ['today',
#   'open',
#   'box',
#   'find',
#   'box',
#   'almost',
#   'half',
#   'around',
#   'filled',
#   'powder',
#   'sure',
#   'correct',
#   'content',
#   'earlier',
#   'purchase'],
#  ['received',
#   'whey',
#   'protein',
#   'used',
#   'one',
#   'scoop',
#   'whey',
#   'water',
#   'mix',
#   'mixed',
#   'properl',
#   'showing',
#   'lump'],
#  ['brand', 'container', 'covered', 'container', 'covered'],
#  ['taste',
#   'food',
#   'doesnt',
#   'taste',
#   'like',
#   'chocolate',
#   'taste',
#   'like',
#   'cocoa',
#   'hyped'],
#  ['bodybuilding'],
#  ['good'],
#  ['recieved', 'damaged', 'product', 'picture', 'attached'],
#  ['im', 'sure', 'product', 'orignal', 'please', 'verify', 'buying'],
#  ['good', 'fake', 'product'],
#  ['original', 'unable', 'trace', 'via', 'authentication', 'code'],
#  ['sealed',
#   'box',
#   'genuine',
#   'importer',
#   'however',
#   'product',
#   'already',
#   'lost',
#   'shelf',
#   'life',
#   'arrival',
#   'bought',
#   'product',
#   'march',
#   'received',
#   'box',
#   'manufactured',
#   'jan',
#   'expiry',
#   'jan'],
#  ['high', 'side', 'effect'],
#  ['poor', 'product'],
#  ['come',
#   'without',
#   'tight',
#   'plastic',
#   'seal',
#   'cap',
#   'looked',
#   'used',
#   'flavour',
#   'absorbency',
#   'good'],
#  ['package',
#   'sent',
#   'manufactured',
#   'though',
#   'expiry',
#   'month',
#   'away',
#   'feel',
#   'good',
#   'consuming'],
#  ['giving',
#   'son',
#   'whey',
#   'protien',
#   'past',
#   'month',
#   'last',
#   'week',
#   'son',
#   'seriously',
#   'ill',
#   'severe',
#   'heart',
#   'palpitation',
#   'breathlessness',
#   'doctor',
#   'attending',
#   'major',
#   'hospital',
#   'said',
#   'whey',
#   'protien',
#   'may',
#   'produced',
#   'checked',
#   'web',
#   'found',
#   'true',
#   'please',
#   'check',
#   'whey',
#   'protien',
#   'arthythmis',
#   'know',
#   'iam',
#   'talking',
#   'almost',
#   'proved',
#   'fatal',
#   'son',
#   'taken',
#   'much',
#   'better'],
#  ['rating',
#   'taste',
#   'flavour',
#   'mocha',
#   'cappuccino',
#   'quite',
#   'terribly',
#   'sweet',
#   'tried',
#   'water',
#   'milk',
#   'sweet',
#   'either',
#   'way',
#   'dont',
#   'think',
#   'health',
#   'conscious',
#   'person',
#   'would',
#   'like',
#   'overly',
#   'sweet',
#   'flavour'],
#  ['ordered',
#   'double',
#   'chocolate',
#   'flavour',
#   'utter',
#   'dissapointment',
#   'even',
#   'feel',
#   'like',
#   'original',
#   'cappucino',
#   'mocha',
#   'much',
#   'much',
#   'better',
#   'dont',
#   'know',
#   'amazon',
#   'would',
#   'take',
#   'back',
#   'opened',
#   'box'],
#  ['sure',
#   'authentic',
#   'taste',
#   'different',
#   'compared',
#   'used',
#   'get',
#   'uk',
#   'authenticate',
#   'covering',
#   'open',
#   'lid',
#   'may',
#   'different',
#   'packaging',
#   'although',
#   'bright',
#   'commodity',
#   'listed',
#   'site',
#   'bit',
#   'relief',
#   'try',
#   'verify',
#   'product',
#   'actually',
#   'imported'],
#  ['first',
#   'ordered',
#   'got',
#   'real',
#   'product',
#   'second',
#   'time',
#   'ordered',
#   'got',
#   'duplicate',
#   'properly',
#   'dissolving',
#   'milk',
#   'water'],
#  ['received',
#   'product',
#   'quantity',
#   'le',
#   'mentioned',
#   'product',
#   'packaging',
#   'also',
#   'damaged'],
#  ['satisfy',
#   'product',
#   'poor',
#   'packaging',
#   'also',
#   'sure',
#   'wheather',
#   'product',
#   'original'],
#  ['product',
#   'delivered',
#   'faulty',
#   'one',
#   'lead',
#   'cover',
#   'opened',
#   'product',
#   'seems',
#   'someone',
#   'already',
#   'used'],
#  ['received',
#   'protein',
#   'powder',
#   'today',
#   'weigh',
#   'two',
#   'pound',
#   'container',
#   'percent',
#   'full',
#   'apparently',
#   'container',
#   'opened',
#   'product',
#   'removed'],
#  ['protien',
#   'powder',
#   'lack',
#   'taste',
#   'impact',
#   'protien',
#   'powder',
#   'provides',
#   'gymmer'],
#  ['effective',
#   'mocha',
#   'cappuccino',
#   'flavour',
#   'might',
#   'unsafe',
#   'consume',
#   'gold',
#   'us',
#   'flavoring',
#   'agent',
#   'sucralose',
#   'acusulfame',
#   'potassium',
#   'controversial',
#   'might',
#   'unsafe',
#   'chemical',
#   'better',
#   'eat',
#   'whole',
#   'food',
#   'using',
#   'supplement',
#   'previously',
#   'used',
#   'flavour',
#   'double',
#   'rich',
#   'chocolate',
#   'flavour',
#   'maybe',
#   'bad',
#   'batch',
#   'french',
#   'vanilla',
#   'icecream',
#   'future',
#   'never',
#   'use'],
#  ['please', 'anyone', 'help', 'me', 'written', 'main', 'labeltell', 'fake'],
#  ['got',
#   'product',
#   'minute',
#   'ago',
#   'putted',
#   'scratch',
#   'bright',
#   'commodity',
#   'bill',
#   'use',
#   'claim',
#   'benefit',
#   'use',
#   'write',
#   'review',
#   'thank'],
#  ['silver',
#   'foil',
#   'anything',
#   'product',
#   'primarily',
#   'plastic',
#   'bottle',
#   'cap',
#   'coverage',
#   'content',
#   'sure',
#   'whether',
#   'genuine',
#   'product',
#   'got',
#   'tripped',
#   'satisfied',
#   'part',
#   'anybody',
#   'else',
#   'face',
#   'problem',
#   'received',
#   'sealed',
#   'bottle'],
#  ['sure',
#   'even',
#   'genuine',
#   'better',
#   'spend',
#   'extra',
#   'money',
#   'go',
#   'offline',
#   'store',
#   'buy',
#   'someone',
#   'ensure',
#   'authentic',
#   'product',
#   'taste',
#   'bad',
#   'even',
#   'dilute',
#   'properly',
#   'smell',
#   'like',
#   'complan'],
#  ['product',
#   'seem',
#   'original',
#   'taste',
#   'different',
#   'original',
#   'better',
#   'buy',
#   'shop',
#   'cost',
#   'different'],
#  ['seal', 'inside', 'container'],
#  ['rocky',
#   'road',
#   'flavour',
#   'seems',
#   'like',
#   'medicine',
#   'bad',
#   'flavour',
#   'really',
#   'disapointed',
#   'recently',
#   'hv',
#   'tried',
#   'iso',
#   'sensation',
#   'mocha',
#   'cuppuchino',
#   'nd',
#   'protein',
#   'vanilla',
#   'nd',
#   'myprotein',
#   'strawberry',
#   'far',
#   'better',
#   'rocky',
#   'road',
#   'although',
#   'mixability',
#   'really',
#   'gud',
#   'iso',
#   'sensation',
#   'myprotein'],
#  ['got', 'yhe', 'product', 'tge', 'seal', 'broken', 'empty'],
#  ['like', 'drinking', 'bournvita'],
#  ['show',
#   'result',
#   'huge',
#   'side',
#   'effect',
#   'leg',
#   'swelled',
#   'become',
#   'reddish',
#   'use',
#   'day'],
#  ['much', 'taste', 'chocolate'],
#  ['recommend',
#   'worth',
#   'investment',
#   'tried',
#   'one',
#   'box',
#   'never',
#   'felt',
#   'giving',
#   'sort',
#   'push',
#   'better',
#   'try',
#   'product',
#   'lfrom',
#   'gnc'],
#  ['best'],
#  ['using',
#   'product',
#   'day',
#   'different',
#   'body',
#   'buy',
#   'product',
#   'waste',
#   'money'],
#  ['authenticity', 'issue'],
#  ['product',
#   'mixing',
#   'properly',
#   'water',
#   'genuine',
#   'product',
#   'mix',
#   'well',
#   'fully',
#   'water',
#   'without',
#   'crystal'],
#  ['container',
#   'tampered',
#   'replacement',
#   'container',
#   'also',
#   'tampered',
#   'asked',
#   'refund',
#   'got',
#   'refund',
#   'picture',
#   'added',
#   'insight'],
#  ['rating',
#   'taking',
#   'back',
#   'intended',
#   'put',
#   'rating',
#   'powder',
#   'old',
#   'get',
#   'dissolved',
#   'milk',
#   'water'],
#  ['flavour', 'bad', 'taste', 'product', 'ineffective'],
#  ['hardly', 'believe', 'authenticity', 'product'],
#  ['buy',
#   'product',
#   'becous',
#   'got',
#   'totally',
#   'fack',
#   'protein',
#   'inside',
#   'box'],
#  ['wrost', 'product'],
#  ['product', 'upto', 'mark', 'mixed', 'product'],
#  ['doubt',
#   'genuine',
#   'taste',
#   'different',
#   'also',
#   'thinner',
#   'scoop',
#   'always',
#   'present',
#   'optimum',
#   'nutrition',
#   'missing'],
#  ['good'],
#  ['box', 'opened', 'already'],
#  ['good', 'per', 'cost'],
#  ['scoop', 'inside', 'package', 'doubt', 'originality'],
#  ['like', 'taste', 'double', 'chocolate', 'way', 'better', 'one'],
#  ['powder', 'produce', 'white', 'layer', 'mixing', 'water', 'please', 'tell'],
#  ['month', 'expiry', 'date', 'left'],
#  ['one',
#   'year',
#   'old',
#   'product',
#   'mfg',
#   'date',
#   'always',
#   'mentioned',
#   'website',
#   'non',
#   'returnable',
#   'item'],
#  ['box',
#   'really',
#   'small',
#   'try',
#   'purchsing',
#   'big',
#   'one',
#   'actually',
#   'expensive',
#   'calculate'],
#  ['show', 'result', 'blot', 'belly'],
#  ['expected'],
#  ['thik', 'thak'],
#  ['jhatoon'],
#  ['anyone',
#   'replace',
#   'content',
#   'box',
#   'reseal',
#   'effortlessly',
#   'quickly',
#   'instead',
#   'pasting',
#   'authentication',
#   'code',
#   'box',
#   'paste',
#   'seal',
#   'inside',
#   'lid'],
#  ['generally',
#   'use',
#   'authenticity',
#   'code',
#   'printed',
#   'box',
#   'get',
#   'verified',
#   'optimum',
#   'nutrition',
#   'website',
#   'sm',
#   'time',
#   'sent',
#   'authentication',
#   'code',
#   'verification',
#   'sm',
#   'system',
#   'response',
#   'tried',
#   'verifying',
#   'website',
#   'work',
#   'either',
#   'genuinely',
#   'doubtful',
#   'whether',
#   'product',
#   'received',
#   'genuine',
#   'kindly',
#   'help'],
#  ['mango',
#   'flavour',
#   'sweet',
#   'many',
#   'artificial',
#   'sweetner',
#   'added',
#   'protein',
#   'good',
#   'quality',
#   'buy',
#   'chocolate',
#   'flavour',
#   'instead'],
#  ['doubt',
#   'whey',
#   'high',
#   'standard',
#   'protein',
#   'want',
#   'good',
#   'protein',
#   'go',
#   'taste',
#   'average',
#   'flavor',
#   'still',
#   'taste',
#   'raw',
#   'horrible',
#   'take',
#   'gulp',
#   'feel',
#   'like',
#   'throwing',
#   'even',
#   'puke',
#   'clearly',
#   'taste',
#   'heavy',
#   'metal',
#   'like',
#   'chewing',
#   'iron',
#   'piece',
#   'buy',
#   'flavor',
#   'buy',
#   'double',
#   'dark',
#   'chocolate',
#   'want',
#   'buy',
#   'cooky',
#   'cream',
#   'flavor',
#   'taste',
#   'good',
#   'overall',
#   'best',
#   'protein',
#   'buy'],
#  ['seal',
#   'opening',
#   'container',
#   'someone',
#   'could',
#   'easily',
#   'removed',
#   'replaced',
#   'content',
#   'container'],
#  ['okk'],
#  ['good', 'product'],
#  ['sent', 'code', 'however', 'get', 'response', 'product', 'verified'],
#  ['beginner'],
#  ['good', 'product', 'doubt', 'like', 'flavor', 'much', 'prefer', 'flavour'],
#  ['nutritional',
#   'composition',
#   'product',
#   'awful',
#   'includes',
#   'sunflower',
#   'oil',
#   'maltodextrin',
#   'worse',
#   'component',
#   'whey',
#   'protein',
#   'cause',
#   'overall',
#   'inflammation',
#   'body',
#   'tasted',
#   'tastebud',
#   'got',
#   'overwhelmed',
#   'artificiality',
#   'clean',
#   'diet',
#   'developed',
#   'headache',
#   'belly',
#   'expanded',
#   'buy',
#   'definitely',
#   'worth',
#   'better',
#   'eat',
#   'boiled',
#   'egg',
#   'altogether',
#   'poison',
#   'full',
#   'artificial',
#   'ingredient',
#   'cheapest',
#   'toxic',
#   'ingredient',
#   'decided',
#   'throw',
#   'garbage'],
#  ['know',
#   'guy',
#   'cannot',
#   'give',
#   'single',
#   'piece',
#   'scopp',
#   'box',
#   'mean',
#   'im',
#   'gonnaa',
#   'know',
#   'exact',
#   'quantity',
#   'needed'],
#  ['first',
#   'time',
#   'consumer',
#   'kind',
#   'whey',
#   'protein',
#   'based',
#   'review',
#   'purchased',
#   'one',
#   'delivery',
#   'smooth',
#   'checked',
#   'content',
#   'verified',
#   'authenticity',
#   'website',
#   'code',
#   'pack',
#   'taken',
#   'vanilla',
#   'ice',
#   'cream',
#   'flavor',
#   'found',
#   'sweet',
#   'taste',
#   'bud'],
#  ['got',
#   'flavor',
#   'reading',
#   'lot',
#   'positive',
#   'comment',
#   'though',
#   'turned',
#   'disappointment',
#   'felt',
#   'bad',
#   'thought',
#   'throwing',
#   'day',
#   'decided',
#   'read',
#   'instruction',
#   'jar',
#   'said',
#   'need',
#   'mix',
#   'ml',
#   'water',
#   'wrong',
#   'mixing',
#   'ml',
#   'water',
#   'perfect',
#   'quantity',
#   'double',
#   'rich',
#   'chocolate',
#   'disliking',
#   'flavor',
#   'try',
#   'ml',
#   'water',
#   'ice',
#   'cube',
#   'drastically',
#   'reduce',
#   'sweetness',
#   'make',
#   'far',
#   'tolerable',
#   'issue',
#   'whey',
#   'quality',
#   'never',
#   'buying',
#   'flavor'],
#  ['box',
#   'came',
#   'packed',
#   'assuming',
#   'original',
#   'however',
#   'leaf',
#   'strange',
#   'taste',
#   'usually',
#   'come',
#   'original',
#   'whey',
#   'sure',
#   'recommend'],
#  ['everything',
#   'great',
#   'per',
#   'mentioned',
#   'macro',
#   'expect',
#   'costly',
#   'offer'],
#  ['get',
#   'like',
#   'dark',
#   'chocolate',
#   'literally',
#   'th',
#   'inti',
#   'bottle',
#   'got',
#   'hang',
#   'taste',
#   'would',
#   'get',
#   'ever',
#   'consuming',
#   'protein',
#   'quite',
#   'sometime',
# ...
#   'protein',
#   'last',
#   'yr',
#   'regularrly',
#   'first',
#   'time',
#   'buy',
#   'amzon',
#   'open',
#   'make',
#   'uneven',
#   'smell',
#   'think',
#   'happen',
#   'due',
#   'transfer',
#   'next',
#   'mrng',
#   'finish',
#   'workout',
#   'usual',
#   'make',
#   'protein',
#   'shake',
#   'make',
#   'unpleasnt',
#   'test',
#   'look',
#   'like',
#   'unhygeine',
#   'prdts',
#   'please',
#   'possible',
#   'buy',
#   'authorized',
#   'distributiors',
#   'becoz',
#   'last',
#   'cause',
#   'nd',
#   'yr',
#   'body',
#   'aware'],
#  ['doubt', 'original', 'anyway', 'made', 'india', 'weird', 'imported'],
#  ['fake',
#   'product',
#   'bar',
#   'code',
#   'truempn',
#   'scanner',
#   'show',
#   'invalid',
#   'please',
#   'buy'],
#  ['bad', 'waste', 'money'],
#  ['iv',
#   'optimum',
#   'nutrition',
#   'gold',
#   'standard',
#   'whey',
#   'since',
#   'year',
#   'used',
#   'purchase',
#   'new',
#   'life',
#   'first',
#   'time',
#   'ordered',
#   'let',
#   'tell',
#   'honestly',
#   'fake',
#   'product',
#   'forget',
#   'mixability',
#   'even',
#   'taste',
#   'far',
#   'cry',
#   'original',
#   'loose',
#   'motion',
#   'ask',
#   'refund'],
#  ['received',
#   'bad',
#   'quality',
#   'mfg',
#   'date',
#   'almost',
#   'year',
#   'back',
#   'got',
#   'foul',
#   'smell',
#   'throwed',
#   'trash',
#   'nt',
#   'availbale',
#   'return',
#   'replace',
#   'waste',
#   'money'],
#  ['fake'],
#  ['reordered',
#   'nt',
#   'got',
#   'seller',
#   'reorder',
#   'clearly',
#   'mean',
#   'need',
#   'everything',
#   'got',
#   'bright',
#   'importer',
#   'require',
#   'earlier',
#   'one',
#   'hr',
#   'registered',
#   'importer',
#   'opened',
#   'returned'],
#  ['receive',
#   'product',
#   'paid',
#   'next',
#   'day',
#   'delivery',
#   'ordered',
#   'two',
#   'item',
#   'received',
#   'item',
#   'dissapointing'],
#  ['brought',
#   'fake',
#   'product',
#   'cheking',
#   'bar',
#   'code',
#   'show',
#   'web',
#   'address',
#   'found',
#   'spelling',
#   'mistake',
#   'importer',
#   'name',
#   'observed',
#   'bright',
#   'commodites',
#   'missing',
#   'spelling',
#   'mistake',
#   'original',
#   'online',
#   'go',
#   'store',
#   'pitch'],
#  ['vomiting', 'soon', 'powder', 'pathetic', 'taste'],
#  ['thought', 'imported', 'usa'],
#  ['ordered',
#   'product',
#   'taste',
#   'nt',
#   'good',
#   'seems',
#   'tht',
#   'product',
#   'nt',
#   'genuine',
#   'protein',
#   'powder',
#   'containing',
#   'completely',
#   'visible',
#   'white',
#   'powder',
#   'like',
#   'structure',
#   'nt',
#   'authentic',
#   'product',
#   'nt',
#   'expectd',
#   'cloudtail',
#   'thought',
#   'good',
#   'seller',
#   'stuff',
#   'ur',
#   'side',
#   'srslly',
#   'disappointed'],
#  ['dont',
#   'know',
#   'supposed',
#   'taste',
#   'taste',
#   'quite',
#   'bad',
#   'wont',
#   'buying'],
#  ['someone',
#   'used',
#   'three',
#   'popular',
#   'brand',
#   'protein',
#   'india',
#   'muscleblaze',
#   'whey',
#   'concentrate',
#   'asitis',
#   'whey',
#   'isolate',
#   'gold',
#   'standard',
#   'would',
#   'like',
#   'give',
#   'honest',
#   'opinion',
#   'come',
#   'effect',
#   'body',
#   'workout',
#   'gold',
#   'standard',
#   'mb',
#   'concentrate',
#   'asitis',
#   'isolate',
#   'brand',
#   'life',
#   'name',
#   'bad',
#   'part',
#   'come',
#   'artifical',
#   'flavour',
#   'sweetners',
#   'leaf',
#   'lingering',
#   'supersweet',
#   'taste',
#   'hour',
#   'mouth',
#   'throat',
#   'make',
#   'harmful',
#   'prolonged',
#   'excessive',
#   'use',
#   'wonder',
#   'big',
#   'famous',
#   'brand',
#   'never',
#   'provided',
#   'unflavoured',
#   'unsweetened',
#   'option',
#   'people',
#   'want',
#   'thing',
#   'inside',
#   'body',
#   'also',
#   'put',
#   'question',
#   'mark',
#   'quality',
#   'whey',
#   'processing',
#   'plant',
#   'deal',
#   'big',
#   'brand',
#   'india',
#   'repurchase',
#   'protein',
#   'powder',
#   'release',
#   'unflavoured',
#   'version'],
#  ['artificial',
#   'sweetener',
#   'sweeter',
#   'sugar',
#   'calorie',
#   'mentioned',
#   'anywhere',
#   'would',
#   'anyone',
#   'want',
#   'sweetener',
#   'supplement',
#   'disappointed',
#   'product'],
#  ['sweet',
#   'like',
#   'syrp',
#   'would',
#   'recommend',
#   'version',
#   'felt',
#   'like',
#   'drinking',
#   'sweet',
#   'candy',
#   'syrp',
#   'sugar',
#   'disaster'],
#  ['product',
#   'fairly',
#   'good',
#   'market',
#   'beginner',
#   'use',
#   'choice',
#   'however',
#   'intermediate',
#   'training',
#   'person',
#   'disliked',
#   'taste',
#   'whey',
#   'used',
#   'mixed',
#   'milk',
#   'water',
#   'consume',
#   'much',
#   'sugary',
#   'taste',
#   'still',
#   'useful',
#   'idea',
#   'portable',
#   'small',
#   'pack',
#   'come',
#   'handy',
#   'actively',
#   'travelling',
#   'without',
#   'muscletech',
#   'whey',
#   'isolate',
#   'protein',
#   'go',
#   'stock',
#   'sometimes',
#   'sooner',
#   'expected'],
#  ['rupee',
#   'pound',
#   'waste',
#   'money',
#   'buy',
#   'product',
#   'atleast',
#   'get',
#   'scammed',
#   'product',
#   'non',
#   'returnable',
#   'reason',
#   'delivering',
#   'damaged',
#   'product',
#   'high',
#   'price',
#   'gm',
#   'protein',
#   'add',
#   'budget',
#   'get',
#   'better',
#   'protein'],
#  ['personally',
#   'like',
#   'dissolving',
#   'shaker',
#   'water',
#   'mixing',
#   'properly',
#   'taste',
#   'drinking',
#   'water'],
#  ['mean', 'show', 'true', 'nature', 'genuine', 'fake'],
#  ['sugary', 'able', 'tolerate', 'even'],
#  ['started',
#   'protein',
#   'powder',
#   'day',
#   'back',
#   'half',
#   'scoop',
#   'exercise',
#   'heavily',
#   'great',
#   'toe',
#   'joint',
#   'paining',
#   'due',
#   'increasing',
#   'uric',
#   'acid',
#   'level',
#   'body',
#   'get',
#   'deposited',
#   'joint'],
#  ['dislike', 'like', 'water'],
#  ['sweet',
#   'much',
#   'added',
#   'sugar',
#   'way',
#   'sweet',
#   'gym',
#   'rat',
#   'limited',
#   'intake',
#   'sweet',
#   'thing'],
#  ['mistake',
#   'overlooked',
#   'brought',
#   'product',
#   'thinking',
#   'least',
#   'kg',
#   'lb',
#   'flavor',
#   'chocolate',
#   'sweet',
#   'used',
#   'unflavored',
#   'protein',
#   'give',
#   'shake',
#   'water',
#   'due',
#   'sweetness',
#   'mix',
#   'daily',
#   'unflavored',
#   'protein',
#   'taste',
#   'better',
#   'recommend',
#   'due',
#   'high',
#   'price',
#   'le',
#   'quantity'],
#  ['taste',
#   'good',
#   'bitter',
#   'taste',
#   'remain',
#   'mouth',
#   'long',
#   'time',
#   'killing',
#   'appetite'],
#  ['using',
#   'protein',
#   'powder',
#   'quite',
#   'sometime',
#   'decided',
#   'try',
#   'brand',
#   'flavour',
#   'good',
#   'consistency',
#   'runny',
#   'compared',
#   'brand',
#   'like',
#   'muscle',
#   'blaze',
#   'tried'],
#  ['guy',
#   'nowadays',
#   'started',
#   'manufacturing',
#   'india',
#   'tirupati',
#   'wellness',
#   'indian',
#   'made',
#   'low',
#   'quality',
#   'may',
#   'effect',
#   'health',
#   'personally',
#   'faced',
#   'acne',
#   'problem',
#   'buy',
#   'imported',
#   'usa',
#   'tag',
#   'bright',
#   'commodity',
#   'official',
#   'importer'],
#  ['received',
#   'year',
#   'old',
#   'stock',
#   'optimum',
#   'nutrition',
#   'whey',
#   'protein',
#   'packet',
#   'totally',
#   'crushed',
#   'never',
#   'buy',
#   'item',
#   'expiry',
#   'date',
#   'cloudtail',
#   'india',
#   'likely',
#   'get',
#   'old',
#   'stock'],
#  ['average'],
#  ['good',
#   'protine',
#   'purchase',
#   'nd',
#   'time',
#   'time',
#   'deliver',
#   'packaged',
#   'open',
#   'seal',
#   'pack',
#   'disappointed'],
#  ['wonder', 'genuine', 'product', 'got', 'skin', 'allergy'],
#  ['good', 'quantity', 'le'],
#  ['sure', 'authentic', 'taste', 'different', 'dissolve', 'easily'],
#  ['date',
#   'expiry',
#   'near',
#   'seems',
#   'importing',
#   'product',
#   'near',
#   'expiry',
#   'offering',
#   'discount'],
#  ['worst'],
#  ['ordered',
#   'cloudtail',
#   'seller',
#   'say',
#   'imported',
#   'bright',
#   'commodity',
#   'scratch',
#   'verify',
#   'authentication',
#   'product',
#   'website',
#   'even',
#   'entering',
#   'code',
#   'getting',
#   'verified',
#   'even',
#   'scanned',
#   'qr',
#   'back',
#   'check',
#   'website',
#   'instead',
#   'showing',
#   'authentication',
#   'shoe',
#   'add',
#   'product',
#   'cart'],
#  ['know',
#   'authenticity',
#   'packet',
#   'whey',
#   'protein',
#   'poor',
#   'condition',
#   'looked',
#   'suspicious',
#   'outside',
#   'scratched',
#   'code',
#   'checked',
#   'seller',
#   'website',
#   'authentic',
#   'still',
#   'looking',
#   'packet',
#   'fresh',
#   'one',
#   'sure',
#   'update',
#   'use'],
#  ['le', 'month', 'left', 'expire'],
#  ['poor'],
#  ['want',
#   'talk',
#   'seller',
#   'bought',
#   'protein',
#   'day',
#   'ago',
#   'still',
#   'get',
#   'result',
#   'want',
#   'know',
#   'reason',
#   'still',
#   'get',
#   'result'],
#  ['nice', 'product', 'price'],
#  ['blend',
#   'well',
#   'taste',
#   'horrible',
#   'double',
#   'rich',
#   'chocolate',
#   'tasteless',
#   'use',
#   'ml',
#   'protein',
#   'shake',
#   'even',
#   'take',
#   'ml',
#   'water',
#   'taste',
#   'like',
#   'chocolate'],
#  ['taste', 'bad', 'think', 'original', 'whey'],
#  ['brand', 'nothing', 'else'],
#  ['well',
#   'pungent',
#   'smell',
#   'crab',
#   'fish',
#   'think',
#   'protein',
#   'powder',
#   'made',
#   'crab',
#   'fish',
#   'nothing',
#   'work',
#   'body',
#   'hormonal',
#   'level',
#   'change',
#   'kindly',
#   'dont',
#   'buy',
#   'product',
#   'instead',
#   'eat',
#   'natural',
#   'protein'],
#  ['cost', 'much', 'product', 'le', 'bought', 'hubby'],
#  ['taste',
#   'quite',
#   'bad',
#   'im',
#   'sure',
#   'supposed',
#   'taste',
#   'adulterated',
#   'taste',
#   'like',
#   'sawdust'],
#  ['look',
#   'quality',
#   'taste',
#   'showroom',
#   'purchase',
#   'need',
#   'recheck',
#   'originality'],
#  ['though',
#   'little',
#   'late',
#   'writing',
#   'review',
#   'product',
#   'product',
#   'seem',
#   'authentic',
#   'good',
#   'taste',
#   'well'],
#  ['product',
#   'taste',
#   'like',
#   'ontotally',
#   'disappointed',
#   'expected',
#   'kind',
#   'service',
#   'amazon',
#   'need',
#   'check',
#   'genuine',
#   'product',
#   'delivery'],
#  ['original',
#   'checked',
#   'bar',
#   'code',
#   'importer',
#   'sticker',
#   'packet',
#   'taste',
#   'nothing',
#   'like',
#   'chocolate',
#   'horrible'],
#  ['good'],
#  ['sabse', 'ghatia', 'test', 'wrost', 'product', 'using', 'day'],
#  ['mixing', 'properly', 'milk', 'confused', 'original'],
#  ['damage', 'product'],
#  ['poor', 'product', 'packaging', 'content', 'leaking'],
#  ['waste'],
#  ['waste'],
#  ['know', 'abt', 'authenticity', 'nt', 'feel', 'energised', 'using'],
#  ['old', 'stock', 'manufactured'],
#  ['good', 'one', 'bad', 'taste'],
#  ['taste',
#   'different',
#   'content',
#   'table',
#   'showing',
#   'different',
#   'percentage',
#   'protene',
#   'doubt',
#   'geneuinity'],
#  ['worthy'],
#  ['good'],
#  ['like'],
#  ['pack', 'torned', 'mean', 'seal', 'open'],
#  ['much', 'worth', 'money'],
#  ['might', 'bodybuilder', 'work'],
#  ['horrible', 'taste'],
#  ['lb', 'give', 'visible', 'result'],
#  ['happy'],
#  ['result'],
#  ['normal',
#   'expiry',
#   'date',
#   'protien',
#   'powder',
#   'year',
#   'exceedes',
#   'buy',
#   'normally',
#   'wont',
#   'eat',
#   'non',
#   'veg',
#   'lag',
#   'protien',
#   'received',
#   'product',
#   'made',
#   'making',
#   'little',
#   'bit',
#   'unhappy',
#   'almost',
#   'coming',
#   'returned',
#   'cloudtail',
#   'seller',
#   'trusty',
#   'one',
#   'proceeding',
#   'taste',
#   'satisfying',
#   'powder',
#   'need',
#   'use',
#   'blender',
#   'make',
#   'dissolve',
#   'completely',
#   'anyway',
#   'brand',
#   'good',
#   'beginnrs',
#   'well'],
#  ['recently',
#   'used',
#   'imported',
#   'whey',
#   'protein',
#   'good',
#   'mixability',
#   'great',
#   'taste',
#   'one',
#   'know',
#   'fake',
#   'original'],
#  ['sure',
#   'problem',
#   'lactose',
#   'received',
#   'duplicate',
#   'package',
#   'nausea',
#   'every',
#   'time',
#   'taken',
#   'stopped',
#   'taking',
#   'try',
#   'puked',
#   'time',
#   'seriously',
#   'suggest',
#   'trial',
#   'pack',
#   'ordering',
#   'big',
#   'pack',
#   'tried',
#   'chocolate',
#   'flavour',
#   'problem'],
#  ['update',
#   'min',
#   'drinking',
#   'powder',
#   'brings',
#   'weird',
#   'sweet',
#   'taste',
#   'mouth',
#   'stay',
#   'several',
#   'hour',
#   'entire',
#   'saliva',
#   'sweet',
#   'mouth',
#   'sweet',
#   'sugary',
#   'sweet',
#   'artificial',
#   'unpleasant',
#   'researched',
#   'google',
#   'found',
#   'many',
#   'people',
#   'get',
#   'weird',
#   'sweet',
#   'mouth',
#   'hr',
#   'consuming',
#   'whey',
#   'gold',
#   'standard',
#   'look',
#   'like',
#   'wont',
#   'order',
#   'life',
#   'star',
#   'amazon',
#   'packaging',
#   'received',
#   'bag',
#   'folded',
#   'cardboard',
#   'sheet',
#   'anybody',
#   'easily',
#   'tamper',
#   'replace',
#   'original',
#   'product',
#   'one',
#   'product',
#   'look',
#   'like',
#   'original'],
#  ['ok'],
#  ['seems',
#   'like',
#   'fake',
#   'one',
#   'proper',
#   'mixing',
#   'milk',
#   'company',
#   'say',
#   'transparent',
#   'spoon',
#   'original',
#   'got',
#   'golden',
#   'spoon',
#   'whatever',
#   'satisfied'],
#  ['feel', 'original', 'product', 'test', 'texture', 'small', 'slit', 'seal'],
#  ['sure', 'product', 'original'],
#  ['seems',
#   'original',
#   'started',
#   'showing',
#   'result',
#   'pretty',
#   'fast',
#   'week',
#   'review',
#   'daysi',
#   'miss',
#   'day',
#   'due',
#   'reason',
#   'thn',
#   'truth',
#   'came',
#   'light',
#   'missing',
#   'day',
#   'muscle',
#   'paining',
#   'stamen',
#   'seemed',
#   'hv',
#   'vanished',
#   'omg',
#   'either',
#   'product',
#   'fake',
#   'contains',
#   'pain',
#   'killer',
#   'actually',
#   'pain',
#   'killer',
#   'drug',
#   'make',
#   'feel',
#   'hv',
#   'become',
#   'strong',
#   'reality',
#   'hv',
#   'causing',
#   'serious',
#   'side',
#   'effect',
#   'ingredient',
#   'dangerous',
#   'health',
#   'long',
#   'term',
#   'guy'],
#  ['right',
#   'one',
#   'old',
#   'purchase',
#   'left',
#   'current',
#   'purchase',
#   'left',
#   'product',
#   'taste',
#   'good',
#   'right',
#   'one',
#   'bit',
#   'skeptical',
#   'authenticity',
#   'authentic',
#   'lost',
#   'quality'],
#  ['item', 'good', 'costly', 'worth', 'much', 'price'],
#  ['update',
#   'mix',
#   'well',
#   'water',
#   'cold',
#   'milk',
#   'dont',
#   'try',
#   'hot',
#   'milk',
#   'result',
#   'used',
#   'packet',
#   'much',
#   'difference',
#   'weight',
#   'update',
#   'using',
#   'week'],
#  ['well',
#   'sure',
#   'protein',
#   'content',
#   'claim',
#   'say',
#   'harmful',
#   'side',
#   'effect',
#   'say',
#   'yummy',
#   'eat',
#   'used',
#   'make',
#   'overnight',
#   'oat',
#   'would',
#   'turn',
#   'chocolate',
#   'pudding',
#   'madd',
#   'worry',
#   'sugar',
#   'content',
#   'healthy',
#   'actually',
#   'like',
#   'sealed',
#   'package',
#   'easy',
#   'use',
#   'dint',
#   'cause',
#   'much',
#   'bloating',
#   'packaging',
#   'product',
#   'seemed',
#   'authentic'],
#  ['good'],
#  ['like'],
#  ['cost', 'may', 'le'],
#  ['weird',
#   'taste',
#   'protein',
#   'felt',
#   'stronger',
#   'flavor',
#   'chocolate',
#   'like',
#   'vanilla',
#   'ice',
#   'cream',
#   'better'],
#  ['seller',
#   'rk',
#   'worldi',
#   'checked',
#   'scratch',
#   'code',
#   'verified',
#   'product',
#   'authentic',
#   'mixability',
#   'smell',
#   'good',
#   'mostly',
#   'negative',
#   'review',
#   'product',
#   'know',
#   'whyfor',
#   'say',
#   'importer',
#   'sticker',
#   'misssing',
#   'manufactured',
#   'india',
#   'mailed',
#   'glanbia',
#   'india',
#   'hard',
#   'confirmation',
#   'genuinity',
#   'product',
#   'got',
#   'reply',
#   'buy',
#   'imported',
#   'one',
#   'next',
#   'time',
#   'market',
#   'supereasy',
#   'verify',
#   'mail',
#   'picture',
#   'detail',
#   'confirm'],
#  ['good', 'product'],
#  ['previously',
#   'bought',
#   'ingredient',
#   'list',
#   'mentioned',
#   'lactase',
#   'enzyme',
#   'lactase',
#   'enzyme',
#   'help',
#   'people',
#   'suffering',
#   'lactose',
#   'intolerance',
#   'digest',
#   'milk',
#   'product',
#   'easily',
#   'however',
#   'time',
#   'mentioned',
#   'ingredient',
#   'list',
#   'whether',
#   'lactase',
#   'enzyme',
#   'also',
#   'product',
#   'image',
#   'available',
#   'side'],
#  ['idk', 'really', 'effective', 'find', 'difference', 'honest'],
#  ['waste',
#   'product',
#   'please',
#   'friend',
#   'buy',
#   'product',
#   'buy',
#   'product',
#   'use',
#   'water',
#   'side',
#   'affect',
#   'casue'],
#  ['normal'],
#  ['average'],
#  ['gum',
#   'airtight',
#   'seal',
#   'strong',
#   'enough',
#   'transfer',
#   'powder',
#   'different',
#   'container',
#   'non',
#   'functional',
#   'seal'],
#  ['received',
#   'product',
#   'today',
#   'look',
#   'genuine',
#   'way',
#   'authenticate',
#   'powder',
#   'inside',
#   'seems',
#   'lost',
#   'flavor',
#   'tried',
#   'double',
#   'rich',
#   'chocolate',
#   'difference',
#   'taste',
#   'smell',
#   'got',
#   'old',
#   'product',
#   'manufactured',
#   'half',
#   'year',
#   'lost',
#   'nutrition',
#   'value',
#   'plus',
#   'taste',
#   'smell',
#   'god',
#   'know',
#   'product',
#   'really',
#   'worth'],
#  ['product',
#   'supposed',
#   'long',
#   'shelf',
#   'life',
#   'one',
#   'expire',
#   'though',
#   'authenticity',
#   'good',
#   'recommend',
#   'going',
#   'outlet',
#   'listed',
#   'website',
#   'purchase',
#   'newly',
#   'manufactured',
#   'product',
#   'one',
#   'expire'],
#  ['ordered',
#   'vanilla',
#   'ice',
#   'cream',
#   'flavor',
#   'got',
#   'dark',
#   'chocolate',
#   'whey',
#   'powder',
#   'product',
#   'good',
#   'wanted',
#   'vanilla',
#   'flavor'],
#  ...]

# %%
import gensim

# %%
model = gensim.models.Word2Vec(words,epochs=50)

# %%
model.wv.index_to_key
# Out:
# ['product',
#  'good',
#  'protein',
#  'taste',
#  'flavour',
#  'like',
#  'whey',
#  'one',
#  'time',
#  'powder',
#  'genuine',
#  'chocolate',
#  'quality',
#  'also',
#  'amazon',
#  'buy',
#  'code',
#  'original',
#  'fake',
#  'seal',
#  'best',
#  'got',
#  'water',
#  'received',
#  'using',
#  'brand',
#  'result',
#  'flavor',
#  'nutrition',
#  'get',
#  'even',
#  'optimum',
#  'go',
#  'box',
#  'date',
#  'month',
#  'year',
#  'double',
#  'day',
#  'india',
#  'scoop',
#  'milk',
#  'well',
#  'used',
#  'use',
#  'better',
#  'bad',
#  'check',
#  'authenticity',
#  'great',
#  'supplement',
#  'seller',
#  'see',
#  'first',
#  'muscle',
#  'know',
#  'authentic',
#  'expiry',
#  'price',
#  'really',
#  'sure',
#  'ordered',
#  'mix',
#  'try',
#  'feel',
#  'could',
#  'take',
#  'different',
#  'packaging',
#  'money',
#  'always',
#  'gold',
#  'rich',
#  'much',
#  'issue',
#  'review',
#  'website',
#  'tried',
#  'bought',
#  'vanilla',
#  'standard',
#  'container',
#  'sticker',
#  'workout',
#  'come',
#  'sweet',
#  'cloudtail',
#  'mango',
#  'return',
#  'make',
#  'would',
#  'seems',
#  'look',
#  'health',
#  'never',
#  'inside',
#  'pack',
#  'old',
#  'thing',
#  'bright',
#  'please',
#  'nice',
#  'order',
#  'body',
#  'purchase',
#  'bit',
#  'say',
#  'doubt',
#  'smell',
#  'importer',
#  'found',
#  'cream',
#  'open',
#  'give',
#  'checked',
#  'need',
#  'gym',
#  'top',
#  'since',
#  'authentication',
#  'customer',
#  'many',
#  'loaded',
#  'mocha',
#  'last',
#  'lb',
#  'think',
#  'imported',
#  'without',
#  'number',
#  'le',
#  'people',
#  'weight',
#  'back',
#  'mixability',
#  'lid',
#  'market',
#  'medium',
#  'commodity',
#  'worth',
#  'side',
#  'work',
#  'way',
#  'shake',
#  'lot',
#  'happy',
#  'recommend',
#  'effect',
#  'jar',
#  'still',
#  'however',
#  'little',
#  'buying',
#  'want',
#  'help',
#  'high',
#  'batch',
#  'made',
#  'scratch',
#  'new',
#  'dont',
#  'delivered',
#  'find',
#  'may',
#  'verified',
#  'amazing',
#  'mixing',
#  'waste',
#  'though',
#  'ever',
#  'manufactured',
#  'opened',
#  'guy',
#  'easily',
#  'easy',
#  'item',
#  'company',
#  'cappuccino',
#  'official',
#  'packet',
#  'indian',
#  'package',
#  'usa',
#  'protien',
#  'almost',
#  'bottom',
#  'something',
#  'video',
#  'kg',
#  'diet',
#  'manufacturing',
#  'must',
#  'already',
#  'qr',
#  'problem',
#  'ok',
#  'overall',
#  'purchased',
#  'mentioned',
#  'compared',
#  'tub',
#  'label',
#  'every',
#  'online',
#  'isolate',
#  'delivery',
#  'content',
#  'per',
#  'sealed',
#  'properly',
#  'nothing',
#  'far',
#  'mixed',
#  'care',
#  'started',
#  'difference',
#  'quite',
#  'getting',
#  'quantity',
#  'half',
#  'consuming',
#  'bar',
#  'everything',
#  'within',
#  'right',
#  'drink',
#  'expensive',
#  'low',
#  'worst',
#  'taking',
#  'due',
#  'week',
#  'going',
#  'lump',
#  'post',
#  'left',
#  'felt',
#  'nd',
#  'next',
#  'coffee',
#  'recovery',
#  'available',
#  'bloating',
#  'disappointed',
#  'love',
#  'enough',
#  'proper',
#  'earlier',
#  'sugar',
#  'either',
#  'duplicate',
#  'life',
#  'big',
#  'glanbia',
#  'actually',
#  'mark',
#  'ice',
#  'experience',
#  'packing',
#  'consume',
#  'site',
#  'show',
#  'refund',
#  'second',
#  'test',
#  'came',
#  'regular',
#  'serving',
#  'trusted',
#  'past',
#  'poor',
#  'given',
#  'plastic',
#  'cost',
#  'awesome',
#  'effective',
#  'texture',
#  'white',
#  'costly',
#  'real',
#  'fine',
#  'able',
#  'two',
#  'someone',
#  'satisfied',
#  'discount',
#  'tampered',
#  'sent',
#  'yes',
#  'bottle',
#  'cap',
#  'damaged',
#  'highly',
#  'cooky',
#  'might',
#  'thought',
#  'giving',
#  'etc',
#  'verify',
#  'making',
#  'completely',
#  'long',
#  'detail',
#  'stock',
#  'food',
#  'world',
#  'tasted',
#  'ml',
#  'expected',
#  'hologram',
#  'kind',
#  'suggest',
#  'amount',
#  'gave',
#  'keep',
#  'spoon',
#  'pretty',
#  'today',
#  'cheaper',
#  'hour',
#  'stomach',
#  'blend',
#  'digest',
#  'verification',
#  'selling',
#  'change',
#  'otherwise',
#  'thanks',
#  'said',
#  'instead',
#  'digestion',
#  'ur',
#  'printed',
#  'receive',
#  'value',
#  'beginner',
#  'written',
#  'taken',
#  'till',
#  'whether',
#  'artificial',
#  'colour',
#  'form',
#  'benefit',
#  'eat',
#  'hope',
#  'fast',
#  'put',
#  'another',
#  'digestive',
#  'drinking',
#  'safe',
#  'sale',
#  'weird',
#  'daily',
#  'definitely',
#  'stuff',
#  'away',
#  'excellent',
#  'hard',
#  'type',
#  'anyone',
#  'usually',
#  'add',
#  'start',
#  'totally',
#  'intake',
#  'supposed',
#  'delicious',
#  'growth',
#  'gm',
#  'added',
#  'expired',
#  'tell',
#  'expire',
#  'anything',
#  'rocky',
#  'reason',
#  'took',
#  'thank',
#  'replacement',
#  'mean',
#  'store',
#  'cause',
#  'trust',
#  'let',
#  'damage',
#  'sm',
#  'ordering',
#  'extreme',
#  'road',
#  'outside',
#  'manufacture',
#  'else',
#  'personally',
#  'mistake',
#  'around',
#  'consumed',
#  'service',
#  'option',
#  'gram',
#  'full',
#  'name',
#  'coming',
#  'wise',
#  'user',
#  'whole',
#  'recently',
#  'along',
#  'friend',
#  'done',
#  'bitter',
#  'inner',
#  'super',
#  'golden',
#  'lactose',
#  'broken',
#  'bag',
#  'alphonso',
#  'missing',
#  'digit',
#  'building',
#  'small',
#  'update',
#  'fitness',
#  'point',
#  'question',
#  'color',
#  'others',
#  'looking',
#  'level',
#  'consistency',
#  'maybe',
#  'cheap',
#  'filled',
#  'reading',
#  'rest',
#  'carry',
#  'dissolve',
#  'opening',
#  'pecan',
#  'seen',
#  'rating',
#  'barcode',
#  'tasting',
#  'se',
#  'call',
#  'star',
#  'multiple',
#  'cover',
#  'choice',
#  'visible',
#  'called',
#  'non',
#  'told',
#  'request',
#  'strong',
#  'pic',
#  'average',
#  'sign',
#  'total',
#  'process',
#  'stopped',
#  'photo',
#  'working',
#  'import',
#  'packed',
#  'stay',
#  'manufacturer',
#  'pain',
#  'previous',
#  'quick',
#  'buyer',
#  'careful',
#  'least',
#  'regarding',
#  'unable',
#  'case',
#  'checking',
#  'distributor',
#  'muscleblaze',
#  'confirm',
#  'image',
#  'rk',
#  'blue',
#  'sachet',
#  'authenticated',
#  'wrong',
#  'superb',
#  'cannot',
#  'primarc',
#  'consumption',
#  'mind',
#  'adulterated',
#  'authenticate',
#  'ingredient',
#  'extremely',
#  'twice',
#  'actual',
#  'increase',
#  'confused',
#  'replaced',
#  'prefer',
#  'strength',
#  'strawberry',
#  'concentrate',
#  'replace',
#  'pure',
#  'mass',
#  'local',
#  'vegetarian',
#  'especially',
#  'intolerant',
#  'important',
#  'system',
#  'worry',
#  'healthy',
#  'believe',
#  'shaker',
#  'avoid',
#  'noticed',
#  'near',
#  'aware',
#  'decided',
#  'saying',
#  'present',
#  'exercise',
#  'perfect',
#  'picture',
#  'correct',
#  'usual',
#  'difficult',
#  'deal',
#  'flour',
#  'cold',
#  'guess',
#  'absolutely',
#  'upto',
#  'showing',
#  'part',
#  'mfg',
#  'bucket',
#  'plant',
#  'although',
#  'smooth',
#  'bodybuilding',
#  'extra',
#  'gain',
#  'experienced',
#  'shop',
#  'source',
#  'plus',
#  'write',
#  'atleast',
#  'transparent',
#  'returnable',
#  'currently',
#  'free',
#  'match',
#  'simply',
#  'worse',
#  'natural',
#  'heavy',
#  'kindly',
#  'attached',
#  'comment',
#  'directly',
#  'fat',
#  'mostly',
#  'condition',
#  'wanted',
#  'place',
#  'higher',
#  'shelf',
#  'mouth',
#  'following',
#  'end',
#  'couple',
#  'egg',
#  'recommended',
#  'clear',
#  'nhi',
#  'isolates',
#  'blaze',
#  'exactly',
#  'expect',
#  'helpful',
#  'placed',
#  'regret',
#  'rather',
#  'slightly',
#  'st',
#  'term',
#  'recieved',
#  'live',
#  'personal',
#  'normal',
#  'outer',
#  'tasty',
#  'seeing',
#  'mention',
#  'cant',
#  'logo',
#  'entire',
#  'build',
#  'provided',
#  'read',
#  'ago',
#  'matter',
#  'close',
#  'writing',
#  'size',
#  'list',
#  'medicine',
#  'flipkart',
#  'probably',
#  'skeptical',
#  'okay',
#  'sweetness',
#  'peanut',
#  'page',
#  'neulife',
#  'light',
#  'butter',
#  'healthkart',
#  'limited',
#  'sell',
#  'mild',
#  'carbs',
#  'feeling',
#  'safety',
#  'yet',
#  'choclate',
#  'originality',
#  'soon',
#  'true',
#  'banana',
#  'spelling',
#  'summer',
#  'sweeter',
#  'opinion',
#  'raw',
#  'supplier',
#  'based',
#  'neck',
#  'purchasing',
#  'contact',
#  'particle',
#  'immediately',
#  'seriously',
#  'genuineness',
#  'clearly',
#  'pay',
#  'thinking',
#  'notice',
#  'eating',
#  'possible',
#  'player',
#  'compare',
#  'stop',
#  'cut',
#  'act',
#  'awful',
#  'nt',
#  'seemed',
#  'pickup',
#  'liked',
#  'feb',
#  'contains',
#  'previously',
#  'expectation',
#  'ask',
#  'mail',
#  'ultimate',
#  'smoothie',
#  'response',
#  'remember',
#  'scan',
#  'orginal',
#  'authorized',
#  'loss',
#  'happened',
#  'excess',
#  'goal',
#  'glutamine',
#  'dark',
#  'support',
#  'yr',
#  'spilled',
#  'scanning',
#  'hai',
#  'pouch',
#  'milkshake',
#  'guide',
#  'legit',
#  'retail',
#  'shaking',
#  'bcaa',
#  'initially',
#  'infocom',
#  'improved',
#  'favourite',
#  'cookie',
#  'gonna',
#  'budget',
#  'negative',
#  'additional',
#  'unique',
#  'trying',
#  'warm',
#  'listed',
#  'covered',
#  'three',
#  'lost',
#  'face',
#  'major',
#  'person',
#  'shipping',
#  'com',
#  'chemical',
#  'energy',
#  'future',
#  'ensure',
#  'myprotein',
#  'asked',
#  'scratched',
#  'power',
#  'compromise',
#  'control',
#  'seem',
#  'blender',
#  'looked',
#  'unfortunately',
#  'offer',
#  'th',
#  'enzyme',
#  'wonder',
#  'hand',
#  'send',
#  'changed',
#  'leaf',
#  'ltd',
#  'understand',
#  'uk',
#  'decide',
#  'rate',
#  'saw',
#  'strange',
#  'fresh',
#  'anyway',
#  'paid',
#  'reply',
#  'particular',
#  'mfd',
#  'similar',
#  'consider',
#  'thick',
#  'performance',
#  'ye',
#  'pvt',
#  'horrible',
#  'sense',
#  'happen',
#  'contacted',
#  'release',
#  'band',
#  'tamper',
#  'ki',
#  'doesnt',
#  'baat',
#  'version',
#  'behind',
#  'liquid',
#  'known',
#  'buck',
#  'gluten',
#  'sweetener',
#  'sold',
#  'research',
#  'text',
#  'unless',
#  'finish',
#  'loading',
#  'window',
#  'play',
#  'solubility',
#  'matching',
#  'isopure',
#  'prime',
#  'unpacked',
#  'doctor',
#  'international',
#  'removed',
#  'setup',
#  'affect',
#  'showcase',
#  'later',
#  'purpose',
#  'steroid',
#  'increased',
#  'foul',
#  'plz',
#  'material',
#  'gained',
#  'fully',
#  'wont',
#  'premium',
#  'koi',
#  'bigger',
#  'sometimes',
#  'chocolaty',
#  'gud',
#  'huge',
#  'tag',
#  'address',
#  'consumer',
#  'compromised',
#  'duration',
#  'nutritional',
#  'single',
#  'bud',
#  'according',
#  'fall',
#  'air',
#  'glad',
#  'shown',
#  'various',
#  'authenticateon',
#  'significant',
#  'tru',
#  'improve',
#  'creates',
#  'complaint',
#  'including',
#  'decent',
#  'reaction',
#  'empty',
#  'claim',
#  'main',
#  'kidney',
#  'third',
#  'tight',
#  'rd',
#  'ke',
#  'ahead',
#  'july',
#  'wish',
#  'ni',
#  'returned',
#  'march',
#  'direct',
#  'tiny',
#  'mixibility',
#  'obviously',
#  'trainer',
#  'fruit',
#  'harmful',
#  'talking',
#  'pound',
#  'message',
#  'hydro',
#  'lack',
#  'provides',
#  'choco',
#  'agent',
#  'tail',
#  'suggested',
#  'hole']

# %%
model.corpus_count
# Out:
# 1279

# %%
model.epochs
# Out:
# 50

# %%
model.wv.similar_by_word('good')
# Out:
# [('great', 0.751893937587738),
#  ('consistency', 0.6998550295829773),
#  ('superb', 0.6924732327461243),
#  ('mixability', 0.6745963096618652),
#  ('excellent', 0.6697230339050293),
#  ('nice', 0.646653413772583),
#  ('bud', 0.6350556015968323),
#  ('usual', 0.6274110674858093),
#  ('tasty', 0.6219296455383301),
#  ('awesome', 0.6179548501968384)]

# %%
model.wv['good']
# Out:
# array([-0.43976548,  0.03309915,  0.2844346 ,  0.43678823,  0.3491831 ,
#        -0.4284263 ,  0.25908753,  0.5058662 ,  0.06840012, -0.24758747,
#         0.2973791 , -0.5934067 , -0.23546243,  0.32088357,  0.179295  ,
#        -0.34334671,  0.2670724 , -0.08078964, -0.4260681 , -0.12562022,
#         0.3756688 , -0.5752819 ,  0.6187374 , -0.45107883, -0.14439213,
#        -0.2568485 ,  0.0060699 , -0.16531044, -0.25026515,  0.71802914,
#         0.36506936, -0.03485382, -0.15248518, -0.55719155, -0.19255084,
#         0.35883802,  0.2187356 ,  0.0430066 , -0.13873908,  0.16610008,
#         0.14691035, -0.45880473, -0.48677245, -0.0026404 ,  0.28585067,
#         0.33771378, -0.4080901 , -0.15588665,  0.40071958, -0.2588895 ,
#         0.6154891 , -0.58072305, -0.0295752 ,  0.24968861, -0.17418225,
#         0.1911807 ,  0.4172493 ,  0.18651024, -0.57012635, -0.20564161,
#        -0.45709425,  0.22296588,  0.14788727, -0.6919746 ,  0.5911713 ,
#         0.42351145,  0.36094522,  0.06271955, -0.25247103, -0.20105723,
#        -0.09935437, -0.06655988, -0.19391027,  0.26346004,  0.14828789,
#         0.09146548, -0.2504053 , -0.13245803, -0.5794746 , -0.0266148 ,
#         0.08674111,  0.3739231 ,  0.01111582,  0.25645897, -0.2914589 ,
#        -0.12776086, -0.05079181, -0.4642396 ,  0.17726162, -0.22903962,
#         0.6382007 , -0.15320042, -0.31958508, -0.16814892,  1.1123619 ,
#        -0.19051772,  0.6542892 , -0.48117733, -0.21652478, -0.5257299 ],
#       dtype=float32)

# %%
model.wv['good'].shape
# Out:
# (100,)

# %%
model.wv['taste']
# Out:
# array([-0.66390854,  0.7250152 , -0.21433486, -0.04274393,  1.1247821 ,
#        -0.2751237 ,  0.8613734 ,  0.36449513,  0.53171945, -0.65564024,
#         0.61097264, -0.07566484,  0.2613155 , -0.28613594,  0.51397914,
#        -0.7422877 ,  0.9561175 , -1.1742407 , -0.343972  , -0.17071989,
#         0.07515676, -0.12022766,  0.32900307,  0.38331258,  0.33659795,
#        -0.34998396, -0.36380067, -0.05849288, -0.6437481 ,  0.14088765,
#         0.08338721, -0.24337003, -0.02814705, -0.9516772 , -0.2974485 ,
#         0.6980209 ,  0.04894378, -0.32268164, -0.49320728,  0.09176594,
#        -0.5368155 , -0.2219238 , -0.06367379,  0.14142069,  0.723084  ,
#        -0.06351229,  0.0441809 , -0.13074137, -0.30752167,  0.11247143,
#         0.5922496 ,  0.13715316,  0.08934395,  0.18383501, -0.47999197,
#        -0.19609822,  0.57685447,  0.12706508, -0.32191512, -0.97572076,
#         0.15040264,  0.32770607,  0.90335345, -0.28492492,  0.4678979 ,
#         0.15038918,  0.11572161,  0.39071578, -0.40920153, -0.53092307,
#        -0.49986482,  0.8512109 , -0.25755784,  0.26652223,  0.05334917,
#        -0.25586885, -1.3292025 ,  0.7408118 , -0.79539126, -0.48382226,
#        -0.18152061,  0.7191704 , -0.18498126,  0.09900397,  0.2811404 ,
#        -0.05702752,  0.46834037,  0.1898494 ,  0.25113237, -0.87433875,
#         0.14977105,  0.2050398 , -0.5265993 , -0.1528319 ,  1.3851085 ,
#         0.4213833 ,  0.56270105, -0.37197316, -0.17718817, -0.64427006],
#       dtype=float32)

# %%
words[0]
# Out:
# ['received',
#  'fake',
#  'product',
#  'worm',
#  'protein',
#  'powder',
#  'look',
#  'like',
#  'lot',
#  'flour',
#  'atta',
#  'mixed',
#  'taste',
#  'awful',
#  'well',
#  'found',
#  'cut',
#  'packaging',
#  'someone',
#  'smartly',
#  'removed',
#  'whey',
#  'added',
#  'flour',
#  'atta',
#  'worm',
#  'put',
#  'label',
#  'back',
#  'cut',
#  'made',
#  'deep',
#  'jar',
#  'user',
#  'notice',
#  'consumed',
#  'lot',
#  'product',
#  'disappointed',
#  'diabetic',
#  'father',
#  'consumed',
#  'visit',
#  'doctor',
#  'twice',
#  'due',
#  'severe',
#  'digestive',
#  'problem',
#  'consuming',
#  'know',
#  'turn',
#  'help']

# %%
def avg_word2vec(doc):
    vectors = [model.wv[word] for word in doc if word in model.wv.index_to_key]
    if len(vectors) > 0:
        return np.mean(vectors, axis=0)
    else:
        # Return a zero vector with the same number of dimensions as your Word2Vec model (e.g., 100 dimensions)
        return np.zeros(model.vector_size)

# %%
pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.5)

# %%
from tqdm import tqdm

# %%
len(X)
# Out:
# 1279

# %%
X_new = np.array(X)

# %%
X_new.shape
# Out:
# (1279, 100)

# %%
X_new[0].shape
# Out:
# (100,)

# %%
import numpy as np

X = np.array(X)

non_zero_indices = [i for i in range(len(X)) if not np.all((X[i] == 0))]

X_filtered = X[non_zero_indices]
y_filtered = df['star_rating'].iloc[non_zero_indices].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_filtered, y_filtered, test_size=0.4, random_state=42)

from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(f"Model accuracy: {accuracy:.4f}")
# Out:
# Model accuracy: 0.4055

# %%
# Sample sentence for prediction
sample_sentence = "worst ever product dont buy"

def preprocess_sentence(sentence):
    sentence = sentence.lower()
    sentence = re.sub('[^a-zA-Z]', ' ', sentence)
    sentence = sentence.split()
    sentence = [lemmatizer.lemmatize(word) for word in sentence]
    return ' '.join(sentence)

processed_sentence = preprocess_sentence(sample_sentence)

words_in_sentence = [processed_sentence.split()]

sentence_vector = avg_word2vec(words_in_sentence[0])

predicted_star_rating = rf_model.predict([sentence_vector])

print(f"Predicted star rating: {predicted_star_rating[0]}")
# Out:
# Predicted star rating: 5

# %% [markdown]
# ## **Try this review sentence**
#
# 1.   worst ever product dont buy
# 2.   Really bad taste unhealthy
# 3.   It's fine, but I wish it had a more natural taste
#
# 4.   The flavor is decent, but the powder leaves a gritty texture
# 5.   Love the flavor, and it mixes easily with no lumps
#
# - Yet to be fine tuned well i tried my best still in progress

# %% [markdown]
# Negative (1-star):
#
# "The powder has a terrible aftertaste and is hard to mix."
# "Caused stomach issues, and the flavor is awful."
# "Very disappointed, didn’t see any benefits and tastes chalky."
# Medium (3-star):
#
# "The flavor is okay, but it doesn’t mix well with water."
# "It's decent, but I’ve had better protein powders for the price."
# "Works fine, but I expected a smoother texture."
# Highly Positive (5-star):
#
# "Amazing taste and blends perfectly, great for post-workout!"
# "Best protein powder I’ve tried, noticeable results in muscle gain."
# "Love the flavor, and it mixes easily with no lumps!"
#
#
# ----------------------------
#
# Negative (1-star):
#
# "The powder clumps up no matter how much I shake it."
# "Really bad flavor, even with milk it’s hard to drink."
# "Gave me bloating and didn’t feel effective at all."
# Medium (3-star):
#
# "The flavor is decent, but the powder leaves a gritty texture."
# "It's fine, but I wish it had a more natural taste."
# "Mixes well enough, but not as smooth as other brands."
# Highly Positive (5-star):
#
# "Fantastic product, mixes well with both water and milk."
# "I love how clean the ingredients are, and it tastes great!"
# "Noticeable improvement in recovery time, highly recommend!"
